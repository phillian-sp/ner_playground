# %%
import pandas as pd
import json

with open("show-transcript_annotations.json", "r", encoding="utf-8") as file:
    df1 = json.load(file)

df1
# Out:
# {'id': '9edcbabaa0f64ce5a7e5d7075911b698',
#  'examples': [{'content': "It looks like something's blocking the camera.",
#    'seen_by': [{'annotator': 'rileydc@stanford.edu', 'annotator_id': 1},
#     {'annotator': 'syu03@stanford.edu', 'annotator_id': 4}],
#    'comments': [],
#    'metadata': {},
#    'example_id': '02b9c685-1c4a-4f4a-b1d5-706fa4eeb1ee',
#    'annotations': [{'end': 8,
#      'tag': 'Behavioral',
#      'start': 3,
#      'value': 'looks',
#      'tag_id': '4e4637f2-48c3-452e-b7db-d1cace295a4d',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '02b9c685-1c4a-4f4a-b1d5-706fa4eeb1ee',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:01:31.409+00:00',
#        'annotator_id': 1},
#       {'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:30:16.201+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '22353200-b7f1-44fb-92bc-02829fc26cd0'},
#     {'end': 13,
#      'tag': 'Mental State',
#      'start': 9,
#      'value': 'like',
#      'tag_id': '2507aaa4-514e-4c68-aa12-4ec759d2625b',
#      'correct': None,
#      'reviewed': False,
#      'example_id': '02b9c685-1c4a-4f4a-b1d5-706fa4eeb1ee',
#      'annotated_by': [{'annotator': None,
#        'timestamp': None,
#        'annotator_id': None}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '3ab2e28f-20b4-424f-a2a2-ef41d8a9fc88'},
#     {'end': 34,
#      'tag': 'Behavioral',
#      'start': 26,
#      'value': 'blocking',
#      'tag_id': '4e4637f2-48c3-452e-b7db-d1cace295a4d',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '02b9c685-1c4a-4f4a-b1d5-706fa4eeb1ee',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:01:34.557+00:00',
#        'annotator_id': 1},
#       {'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:30:16.206+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '47637138-680b-400a-8283-1491b4e78257'},
#     {'end': 45,
#      'tag': 'Artifacts',
#      'start': 39,
#      'value': 'camera',
#      'tag_id': '93766023-3257-4bed-8223-6f91c904c834',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '02b9c685-1c4a-4f4a-b1d5-706fa4eeb1ee',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:30:16.208+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:01:36.235+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '758c1ef7-1c63-4d55-9f52-66911c082951'}],
#    'classifications': []},
#   {'content': 'So she must be feeling the pressure to make it perfect.',
#    'seen_by': [{'annotator': 'rileydc@stanford.edu', 'annotator_id': 1},
#     {'annotator': 'syu03@stanford.edu', 'annotator_id': 4}],
#    'comments': [],
#    'metadata': {},
#    'example_id': '14885fae-8df4-4c3a-b85f-ad520d029205',
#    'annotations': [{'end': 22,
#      'tag': 'Mental State',
#      'start': 15,
#      'value': 'feeling',
#      'tag_id': '2507aaa4-514e-4c68-aa12-4ec759d2625b',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '14885fae-8df4-4c3a-b85f-ad520d029205',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:26:58.11+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:53:08.759+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '85e559da-c378-4e7a-b65a-dfe3d66bec5e'},
#     {'end': 35,
#      'tag': 'Mental State',
#      'start': 27,
#      'value': 'pressure',
#      'tag_id': '2507aaa4-514e-4c68-aa12-4ec759d2625b',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '14885fae-8df4-4c3a-b85f-ad520d029205',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:53:18.009+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '27bb8653-1adc-4ef7-a176-3f5c7ebb1828'},
#     {'end': 43,
#      'tag': 'Behavioral',
#      'start': 39,
#      'value': 'make',
#      'tag_id': '4e4637f2-48c3-452e-b7db-d1cace295a4d',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '14885fae-8df4-4c3a-b85f-ad520d029205',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:53:08.764+00:00',
#        'annotator_id': 1},
#       {'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:26:58.113+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'd870e186-a026-40f3-979b-71f4d0f09c50'},
#     {'end': 6,
#      'tag': 'Biological Kind',
#      'start': 3,
#      'value': 'she',
#      'tag_id': 'b3c56c74-2d45-483d-945d-9103cf870c36',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '14885fae-8df4-4c3a-b85f-ad520d029205',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:53:08.75+00:00',
#        'annotator_id': 1},
#       {'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:26:58.108+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '8c6e1e75-b38c-4591-bd8a-24327a2f0b32'},
#     {'end': 54,
#      'tag': 'Normative Feature',
#      'start': 47,
#      'value': 'perfect',
#      'tag_id': '81d95dea-443c-4f17-9c59-090e5377b894',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '14885fae-8df4-4c3a-b85f-ad520d029205',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:53:08.769+00:00',
#        'annotator_id': 1},
#       {'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:26:58.114+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'ab5214e0-99d8-4d56-bca6-b3658f083a2a'}],
#    'classifications': []},
#   {'content': 'Let us all just close our eyes, and focus',
#    'seen_by': [{'annotator': 'rileydc@stanford.edu', 'annotator_id': 1},
#     {'annotator': 'syu03@stanford.edu', 'annotator_id': 4}],
#    'comments': [],
#    'metadata': {},
#    'example_id': '14c2bcf2-a9b4-4d30-aed1-49de0670d691',
#    'annotations': [{'end': 30,
#      'tag': 'Biological Kind',
#      'start': 26,
#      'value': 'eyes',
#      'tag_id': 'b3c56c74-2d45-483d-945d-9103cf870c36',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '14c2bcf2-a9b4-4d30-aed1-49de0670d691',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:00:57.904+00:00',
#        'annotator_id': 1},
#       {'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:29:53.123+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '3af97b97-c22d-4f05-81c9-c62dc5fe18f3'},
#     {'end': 6,
#      'tag': 'Biological Kind',
#      'start': 4,
#      'value': 'us',
#      'tag_id': 'b3c56c74-2d45-483d-945d-9103cf870c36',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '14c2bcf2-a9b4-4d30-aed1-49de0670d691',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:29:53.119+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:00:57.887+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'd7343f29-992b-40b7-b5b7-28b3e33ac4d4'},
#     {'end': 41,
#      'tag': 'Behavioral',
#      'start': 36,
#      'value': 'focus',
#      'tag_id': '4e4637f2-48c3-452e-b7db-d1cace295a4d',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '14c2bcf2-a9b4-4d30-aed1-49de0670d691',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:29:53.125+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:01:02.907+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '1d0bee25-f33d-4710-ab05-d26f47624bef'},
#     {'end': 21,
#      'tag': 'Behavioral',
#      'start': 16,
#      'value': 'close',
#      'tag_id': '4e4637f2-48c3-452e-b7db-d1cace295a4d',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '14c2bcf2-a9b4-4d30-aed1-49de0670d691',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:29:53.121+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:00:57.898+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '8ff54c92-611d-44dc-afe7-e510fdad0e0b'}],
#    'classifications': []},
#   {'content': 'We brought the hoops to practice our tricks.',
#    'seen_by': [{'annotator': 'rileydc@stanford.edu', 'annotator_id': 1},
#     {'annotator': 'syu03@stanford.edu', 'annotator_id': 4}],
#    'comments': [],
#    'metadata': {},
#    'example_id': '1e991536-4186-4fad-8c6f-5cdf9826b6b1',
#    'annotations': [{'end': 32,
#      'tag': 'Behavioral',
#      'start': 24,
#      'value': 'practice',
#      'tag_id': '4e4637f2-48c3-452e-b7db-d1cace295a4d',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '1e991536-4186-4fad-8c6f-5cdf9826b6b1',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:27:55.178+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:56:05.257+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '53d536ee-5d19-4dab-9ddf-5cfcb7073c2b'},
#     {'end': 20,
#      'tag': 'Artifacts',
#      'start': 15,
#      'value': 'hoops',
#      'tag_id': '93766023-3257-4bed-8223-6f91c904c834',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '1e991536-4186-4fad-8c6f-5cdf9826b6b1',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:27:55.176+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:56:03.138+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '8e8091c4-8eda-49c3-a81d-60d53e09f47d'},
#     {'end': 2,
#      'tag': 'Biological Kind',
#      'start': 0,
#      'value': 'We',
#      'tag_id': 'b3c56c74-2d45-483d-945d-9103cf870c36',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '1e991536-4186-4fad-8c6f-5cdf9826b6b1',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:56:00.391+00:00',
#        'annotator_id': 1},
#       {'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:27:53.381+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'b016e4f6-473a-4585-95c6-1d278793869c'},
#     {'end': 43,
#      'tag': 'Behavioral',
#      'start': 37,
#      'value': 'tricks',
#      'tag_id': '4e4637f2-48c3-452e-b7db-d1cace295a4d',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '1e991536-4186-4fad-8c6f-5cdf9826b6b1',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:27:55.179+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:56:06.384+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '8b548066-bd56-411b-bc49-15b48f3d884a'},
#     {'end': 10,
#      'tag': 'Behavioral',
#      'start': 3,
#      'value': 'brought',
#      'tag_id': '4e4637f2-48c3-452e-b7db-d1cace295a4d',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '1e991536-4186-4fad-8c6f-5cdf9826b6b1',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:27:54.536+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:56:00.401+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'a52a0c57-e7e5-40da-99a7-2d7683e2d798'}],
#    'classifications': []},
#   {'content': "We'll check our sunrise charts at the station.",
#    'seen_by': [{'annotator': 'rileydc@stanford.edu', 'annotator_id': 1},
#     {'annotator': 'syu03@stanford.edu', 'annotator_id': 4}],
#    'comments': [],
#    'metadata': {},
#    'example_id': '250801e7-51dc-4735-8a3e-c59d1589dea3',
#    'annotations': [{'end': 2,
#      'tag': 'Biological Kind',
#      'start': 0,
#      'value': 'We',
#      'tag_id': 'b3c56c74-2d45-483d-945d-9103cf870c36',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '250801e7-51dc-4735-8a3e-c59d1589dea3',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T02:56:58.304+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:37:46.053+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '2feb53f5-9169-4b42-a014-ab3983355747'},
#     {'end': 45,
#      'tag': 'Social Kind/Role',
#      'start': 38,
#      'value': 'station',
#      'tag_id': 'c2d08238-bcff-4c44-af7c-74c991a2afb3',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '250801e7-51dc-4735-8a3e-c59d1589dea3',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:38:05.159+00:00',
#        'annotator_id': 1},
#       {'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T02:56:58.312+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '295d864c-6998-4480-9d96-b2b9b5ef145f'},
#     {'end': 11,
#      'tag': 'Behavioral',
#      'start': 6,
#      'value': 'check',
#      'tag_id': '4e4637f2-48c3-452e-b7db-d1cace295a4d',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '250801e7-51dc-4735-8a3e-c59d1589dea3',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T02:56:58.306+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:37:50.259+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'd2bae38d-f1d9-4285-acfe-2db8b19096db'},
#     {'end': 23,
#      'tag': 'Non-Living Kind',
#      'start': 16,
#      'value': 'sunrise',
#      'tag_id': 'a4288773-f6c5-4bc8-8dff-2b16b8f4787e',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '250801e7-51dc-4735-8a3e-c59d1589dea3',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T02:56:58.308+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:37:52.887+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'f1902a39-cbbc-432f-a370-b898c032a4a7'},
#     {'end': 30,
#      'tag': 'Artifacts',
#      'start': 24,
#      'value': 'charts',
#      'tag_id': '93766023-3257-4bed-8223-6f91c904c834',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '250801e7-51dc-4735-8a3e-c59d1589dea3',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:37:56.341+00:00',
#        'annotator_id': 1},
#       {'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T02:56:58.31+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'fdbe10df-abb0-4de7-b315-939a75bed6ae'}],
#    'classifications': []},
#   {'content': 'All three of you grandpups will have to wait till the wedding day.',
#    'seen_by': [{'annotator': 'rileydc@stanford.edu', 'annotator_id': 1},
#     {'annotator': 'syu03@stanford.edu', 'annotator_id': 4}],
#    'comments': [],
#    'metadata': {},
#    'example_id': '31e1f3c8-3dfa-401c-8b38-6b30b754db05',
#    'annotations': [{'end': 9,
#      'tag': 'Perceptual',
#      'start': 4,
#      'value': 'three',
#      'tag_id': '3302eb94-c347-42d4-a94e-fa696faadced',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '31e1f3c8-3dfa-401c-8b38-6b30b754db05',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:08:35.364+00:00',
#        'annotator_id': 1},
#       {'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:33:17.927+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'e62d2745-2ad2-416e-80cf-c2ff084ee3e7'},
#     {'end': 44,
#      'tag': 'Behavioral',
#      'start': 40,
#      'value': 'wait',
#      'tag_id': '4e4637f2-48c3-452e-b7db-d1cace295a4d',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '31e1f3c8-3dfa-401c-8b38-6b30b754db05',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:33:17.938+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:08:35.386+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '0cbd4d0a-a336-4dd7-a635-be066183f1af'},
#     {'end': 26,
#      'tag': 'Biological Kind',
#      'start': 17,
#      'value': 'grandpups',
#      'tag_id': 'b3c56c74-2d45-483d-945d-9103cf870c36',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '31e1f3c8-3dfa-401c-8b38-6b30b754db05',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:33:17.935+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:08:48.315+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '69500f79-edeb-4c31-86a2-a7d3ab9220a4'},
#     {'end': 65,
#      'tag': 'Non-Living Kind',
#      'start': 62,
#      'value': 'day',
#      'tag_id': 'a4288773-f6c5-4bc8-8dff-2b16b8f4787e',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '31e1f3c8-3dfa-401c-8b38-6b30b754db05',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:08:35.391+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'ec52b39b-6f91-472f-9c31-42a27c88afa3'},
#     {'end': 16,
#      'tag': 'Biological Kind',
#      'start': 13,
#      'value': 'you',
#      'tag_id': 'b3c56c74-2d45-483d-945d-9103cf870c36',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '31e1f3c8-3dfa-401c-8b38-6b30b754db05',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:33:17.931+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'eafdb611-c59f-4e4d-bd37-38d2e7b04a2f'},
#     {'end': 16,
#      'tag': 'Anthropomorphized',
#      'start': 13,
#      'value': 'you',
#      'tag_id': '3d4327e2-56d5-4da0-a591-1aac6ff5fa9d',
#      'correct': False,
#      'reviewed': True,
#      'example_id': '31e1f3c8-3dfa-401c-8b38-6b30b754db05',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:08:43.884+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'd30a10ae-8a3a-4764-a705-fca80729fa32'},
#     {'end': 36,
#      'tag': 'Behavioral',
#      'start': 32,
#      'value': 'have',
#      'tag_id': '4e4637f2-48c3-452e-b7db-d1cace295a4d',
#      'correct': None,
#      'reviewed': False,
#      'example_id': '31e1f3c8-3dfa-401c-8b38-6b30b754db05',
#      'annotated_by': [{'annotator': None,
#        'timestamp': None,
#        'annotator_id': None}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'a9f376e2-3211-4fd8-8eab-cb5949b13f5f'},
#     {'end': 61,
#      'tag': 'Social Kind/Role',
#      'start': 54,
#      'value': 'wedding',
#      'tag_id': 'c2d08238-bcff-4c44-af7c-74c991a2afb3',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '31e1f3c8-3dfa-401c-8b38-6b30b754db05',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:08:52.68+00:00',
#        'annotator_id': 1},
#       {'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:33:17.94+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '857854cf-7e6e-41f2-a4cb-de457522c056'}],
#    'classifications': []},
#   {'content': 'According to the Student Body Constitution, Any candidate who resigns voluntarily may transfer their signatures to another candidate.',
#    'seen_by': [{'annotator': 'rileydc@stanford.edu', 'annotator_id': 1},
#     {'annotator': 'syu03@stanford.edu', 'annotator_id': 4}],
#    'comments': [],
#    'metadata': {},
#    'example_id': '340d6043-c969-4240-a176-bef6132fbecd',
#    'annotations': [{'end': 42,
#      'tag': 'Social Kind/Role',
#      'start': 17,
#      'value': 'Student Body Constitution',
#      'tag_id': 'c2d08238-bcff-4c44-af7c-74c991a2afb3',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '340d6043-c969-4240-a176-bef6132fbecd',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:33:31.719+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '7add6f6c-e73f-460a-a04e-97c36606092d'},
#     {'end': 69,
#      'tag': 'Behavioral',
#      'start': 62,
#      'value': 'resigns',
#      'tag_id': '4e4637f2-48c3-452e-b7db-d1cace295a4d',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '340d6043-c969-4240-a176-bef6132fbecd',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:33:57.236+00:00',
#        'annotator_id': 1},
#       {'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T02:55:52.342+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'a1852cf5-eea1-4e11-8d14-204411ee61a0'},
#     {'end': 29,
#      'tag': 'Biological Kind',
#      'start': 25,
#      'value': 'Body',
#      'tag_id': 'b3c56c74-2d45-483d-945d-9103cf870c36',
#      'correct': False,
#      'reviewed': True,
#      'example_id': '340d6043-c969-4240-a176-bef6132fbecd',
#      'annotated_by': [{'annotator': None,
#        'timestamp': None,
#        'annotator_id': None}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'e9b9845e-42ec-4549-9823-f3c767990cd1'},
#     {'end': 100,
#      'tag': 'Anthropomorphized',
#      'start': 95,
#      'value': 'their',
#      'tag_id': '3d4327e2-56d5-4da0-a591-1aac6ff5fa9d',
#      'correct': None,
#      'reviewed': False,
#      'example_id': '340d6043-c969-4240-a176-bef6132fbecd',
#      'annotated_by': [{'annotator': None,
#        'timestamp': None,
#        'annotator_id': None}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'de02ec5a-15d8-4a60-a812-6b7e02f69d21'},
#     {'end': 81,
#      'tag': 'Behavioral',
#      'start': 70,
#      'value': 'voluntarily',
#      'tag_id': '4e4637f2-48c3-452e-b7db-d1cace295a4d',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '340d6043-c969-4240-a176-bef6132fbecd',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:33:59.112+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '27388684-d450-4e1e-843d-f55b6edd116d'},
#     {'end': 111,
#      'tag': 'Artifacts',
#      'start': 101,
#      'value': 'signatures',
#      'tag_id': '93766023-3257-4bed-8223-6f91c904c834',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '340d6043-c969-4240-a176-bef6132fbecd',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T02:55:52.349+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:34:04.527+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '79543653-133b-48bc-b620-4fd265700acd'},
#     {'end': 94,
#      'tag': 'Behavioral',
#      'start': 86,
#      'value': 'transfer',
#      'tag_id': '4e4637f2-48c3-452e-b7db-d1cace295a4d',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '340d6043-c969-4240-a176-bef6132fbecd',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:34:00.856+00:00',
#        'annotator_id': 1},
#       {'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T02:55:52.346+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '7335390b-a309-41d9-b327-0b359b00cd17'},
#     {'end': 132,
#      'tag': 'Social Kind/Role',
#      'start': 123,
#      'value': 'candidate',
#      'tag_id': 'c2d08238-bcff-4c44-af7c-74c991a2afb3',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '340d6043-c969-4240-a176-bef6132fbecd',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T02:55:52.353+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:34:08.788+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '6d3d7ce4-93f7-4bea-9c3c-66bffdf85f25'},
#     {'end': 57,
#      'tag': 'Social Kind/Role',
#      'start': 48,
#      'value': 'candidate',
#      'tag_id': 'c2d08238-bcff-4c44-af7c-74c991a2afb3',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '340d6043-c969-4240-a176-bef6132fbecd',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T02:55:52.34+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:33:53.724+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '360c56bf-7664-4f70-ae9a-564e8f13cfec'}],
#    'classifications': []},
#   {'content': 'I spent so much of me life trying to hunt down the infamous landshark, and now that I found ye, I be lost, like a sailor without a compass',
#    'seen_by': [{'annotator': 'rileydc@stanford.edu', 'annotator_id': 1},
#     {'annotator': 'syu03@stanford.edu', 'annotator_id': 4}],
#    'comments': [],
#    'metadata': {},
#    'example_id': '4be2b507-6f17-40f0-bc5e-aca322c946c7',
#    'annotations': [{'end': 1,
#      'tag': 'Biological Kind',
#      'start': 0,
#      'value': 'I',
#      'tag_id': 'b3c56c74-2d45-483d-945d-9103cf870c36',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '4be2b507-6f17-40f0-bc5e-aca322c946c7',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:32:37.295+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'ae47a8ec-2623-4e76-a399-c0429061f08b'},
#     {'end': 138,
#      'tag': 'Artifacts',
#      'start': 131,
#      'value': 'compass',
#      'tag_id': '93766023-3257-4bed-8223-6f91c904c834',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '4be2b507-6f17-40f0-bc5e-aca322c946c7',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:32:32.628+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:08:05.836+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'aa68ba06-1327-40b2-9a6e-431ad9447083'},
#     {'end': 91,
#      'tag': 'Behavioral',
#      'start': 86,
#      'value': 'found',
#      'tag_id': '4e4637f2-48c3-452e-b7db-d1cace295a4d',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '4be2b507-6f17-40f0-bc5e-aca322c946c7',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:07:24.125+00:00',
#        'annotator_id': 1},
#       {'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:32:32.618+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '823b10d0-10ae-45fd-ae04-e30aafa8fbf4'},
#     {'end': 21,
#      'tag': 'Biological Kind',
#      'start': 19,
#      'value': 'me',
#      'tag_id': 'b3c56c74-2d45-483d-945d-9103cf870c36',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '4be2b507-6f17-40f0-bc5e-aca322c946c7',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:07:24.104+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '30dc8bfb-4042-4912-91e9-88161871c29e'},
#     {'end': 33,
#      'tag': 'Behavioral',
#      'start': 27,
#      'value': 'trying',
#      'tag_id': '4e4637f2-48c3-452e-b7db-d1cace295a4d',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '4be2b507-6f17-40f0-bc5e-aca322c946c7',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:32:32.605+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:07:24.113+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'a41d1457-6dda-47fd-8027-c3ec6e700383'},
#     {'end': 97,
#      'tag': 'Biological Kind',
#      'start': 96,
#      'value': 'I',
#      'tag_id': 'b3c56c74-2d45-483d-945d-9103cf870c36',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '4be2b507-6f17-40f0-bc5e-aca322c946c7',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:07:55.859+00:00',
#        'annotator_id': 1},
#       {'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:32:52.396+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'c90a4927-1b8f-4958-a8e5-af6029b9a2cf'},
#     {'end': 26,
#      'tag': 'Biological Kind',
#      'start': 22,
#      'value': 'life',
#      'tag_id': 'b3c56c74-2d45-483d-945d-9103cf870c36',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '4be2b507-6f17-40f0-bc5e-aca322c946c7',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:07:24.109+00:00',
#        'annotator_id': 1},
#       {'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:32:32.603+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '9eb007b9-882b-4477-bf18-afd382ce9bb5'},
#     {'end': 94,
#      'tag': 'Biological Kind',
#      'start': 92,
#      'value': 'ye',
#      'tag_id': 'b3c56c74-2d45-483d-945d-9103cf870c36',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '4be2b507-6f17-40f0-bc5e-aca322c946c7',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:32:50.55+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:07:57.631+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'cb3a8da5-4fa6-4916-a0b0-7993e9f8d786'},
#     {'end': 69,
#      'tag': 'Biological Kind',
#      'start': 60,
#      'value': 'landshark',
#      'tag_id': 'b3c56c74-2d45-483d-945d-9103cf870c36',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '4be2b507-6f17-40f0-bc5e-aca322c946c7',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:32:32.612+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:07:43.496+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '62fab004-cc6b-4d35-861c-422c9debc205'},
#     {'end': 1,
#      'tag': 'Anthropomorphized',
#      'start': 0,
#      'value': 'I',
#      'tag_id': '3d4327e2-56d5-4da0-a591-1aac6ff5fa9d',
#      'correct': False,
#      'reviewed': True,
#      'example_id': '4be2b507-6f17-40f0-bc5e-aca322c946c7',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:07:24.087+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '44cb31d1-474a-4ba5-b097-ce5de92c3b5e'},
#     {'end': 7,
#      'tag': 'Behavioral',
#      'start': 2,
#      'value': 'spent',
#      'tag_id': '4e4637f2-48c3-452e-b7db-d1cace295a4d',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '4be2b507-6f17-40f0-bc5e-aca322c946c7',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:32:32.597+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:07:24.099+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '6bdac088-4ccd-4a6b-b040-9be83951c6d6'},
#     {'end': 46,
#      'tag': 'Relation',
#      'start': 42,
#      'value': 'down',
#      'tag_id': '4ae5d3ef-e700-4ab3-8e95-d3aa1fb17007',
#      'correct': None,
#      'reviewed': False,
#      'example_id': '4be2b507-6f17-40f0-bc5e-aca322c946c7',
#      'annotated_by': [{'annotator': None,
#        'timestamp': None,
#        'annotator_id': None}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'de70a850-4bb3-4dbf-94ce-f43b3e237475'},
#     {'end': 41,
#      'tag': 'Behavioral',
#      'start': 37,
#      'value': 'hunt',
#      'tag_id': '4e4637f2-48c3-452e-b7db-d1cace295a4d',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '4be2b507-6f17-40f0-bc5e-aca322c946c7',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:07:26.994+00:00',
#        'annotator_id': 1},
#       {'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:32:32.607+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'dea1d819-73d2-436c-b0c9-0960104652d4'},
#     {'end': 105,
#      'tag': 'Behavioral',
#      'start': 101,
#      'value': 'lost',
#      'tag_id': '4e4637f2-48c3-452e-b7db-d1cace295a4d',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '4be2b507-6f17-40f0-bc5e-aca322c946c7',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:07:24.132+00:00',
#        'annotator_id': 1},
#       {'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:32:32.623+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '6803d9a3-0d8a-4bc6-b578-d32976a3c7b0'},
#     {'end': 97,
#      'tag': 'Anthropomorphized',
#      'start': 96,
#      'value': 'I',
#      'tag_id': '3d4327e2-56d5-4da0-a591-1aac6ff5fa9d',
#      'correct': False,
#      'reviewed': True,
#      'example_id': '4be2b507-6f17-40f0-bc5e-aca322c946c7',
#      'annotated_by': [{'annotator': None,
#        'timestamp': None,
#        'annotator_id': None}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'e7e7b4eb-47fb-444e-902a-0258a845dcca'},
#     {'end': 59,
#      'tag': 'Normative Feature',
#      'start': 51,
#      'value': 'infamous',
#      'tag_id': '81d95dea-443c-4f17-9c59-090e5377b894',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '4be2b507-6f17-40f0-bc5e-aca322c946c7',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:07:40.698+00:00',
#        'annotator_id': 1},
#       {'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:32:32.61+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '8bbca167-00f4-449c-81f8-a3a93073416a'},
#     {'end': 111,
#      'tag': 'Mental State',
#      'start': 107,
#      'value': 'like',
#      'tag_id': '2507aaa4-514e-4c68-aa12-4ec759d2625b',
#      'correct': None,
#      'reviewed': False,
#      'example_id': '4be2b507-6f17-40f0-bc5e-aca322c946c7',
#      'annotated_by': [{'annotator': None,
#        'timestamp': None,
#        'annotator_id': None}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '0f755ee0-1d87-4a31-9c30-64978456e774'},
#     {'end': 85,
#      'tag': 'Anthropomorphized',
#      'start': 84,
#      'value': 'I',
#      'tag_id': '3d4327e2-56d5-4da0-a591-1aac6ff5fa9d',
#      'correct': False,
#      'reviewed': True,
#      'example_id': '4be2b507-6f17-40f0-bc5e-aca322c946c7',
#      'annotated_by': [{'annotator': None,
#        'timestamp': None,
#        'annotator_id': None}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '02df4cd4-6bbd-488e-9898-b2f56c7799cc'},
#     {'end': 85,
#      'tag': 'Biological Kind',
#      'start': 84,
#      'value': 'I',
#      'tag_id': 'b3c56c74-2d45-483d-945d-9103cf870c36',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '4be2b507-6f17-40f0-bc5e-aca322c946c7',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:07:47.55+00:00',
#        'annotator_id': 1},
#       {'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:32:48.144+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '39882c00-41ab-4a57-9775-2e92f8ccdfb8'},
#     {'end': 120,
#      'tag': 'Social Kind/Role',
#      'start': 114,
#      'value': 'sailor',
#      'tag_id': 'c2d08238-bcff-4c44-af7c-74c991a2afb3',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '4be2b507-6f17-40f0-bc5e-aca322c946c7',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:08:02.061+00:00',
#        'annotator_id': 1},
#       {'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:32:32.626+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '37bb97b7-b5f0-4e55-a904-908ff457c728'}],
#    'classifications': []},
#   {'content': "PRINCESS CELESTIA'S A LITTLE BUSY GETTING READY FOR THE SUMMER SUN CELEBRATION.",
#    'seen_by': [{'annotator': 'rileydc@stanford.edu', 'annotator_id': 1},
#     {'annotator': 'syu03@stanford.edu', 'annotator_id': 4}],
#    'comments': [],
#    'metadata': {},
#    'example_id': '6b763b00-ef9b-4042-955d-6945930fc93c',
#    'annotations': [{'end': 41,
#      'tag': 'Behavioral',
#      'start': 34,
#      'value': 'GETTING',
#      'tag_id': '4e4637f2-48c3-452e-b7db-d1cace295a4d',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '6b763b00-ef9b-4042-955d-6945930fc93c',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:20:25.21+00:00',
#        'annotator_id': 1},
#       {'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T02:52:03.793+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '6cf782de-da3d-4144-bd9d-49a21077071c'},
#     {'end': 51,
#      'tag': 'Purpose',
#      'start': 48,
#      'value': 'FOR',
#      'tag_id': 'dd07eb87-383b-46b8-89c7-657bb418576d',
#      'correct': None,
#      'reviewed': False,
#      'example_id': '6b763b00-ef9b-4042-955d-6945930fc93c',
#      'annotated_by': [{'annotator': None,
#        'timestamp': None,
#        'annotator_id': None}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '4facea67-2ba6-4a87-a2ae-1fec32ee9733'},
#     {'end': 66,
#      'tag': 'Non-Living Kind',
#      'start': 63,
#      'value': 'SUN',
#      'tag_id': 'a4288773-f6c5-4bc8-8dff-2b16b8f4787e',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '6b763b00-ef9b-4042-955d-6945930fc93c',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T02:52:03.796+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:20:25.225+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '7c52e45b-f436-436b-90e1-48c02a71c375'},
#     {'end': 62,
#      'tag': 'Non-Living Kind',
#      'start': 56,
#      'value': 'SUMMER',
#      'tag_id': 'a4288773-f6c5-4bc8-8dff-2b16b8f4787e',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '6b763b00-ef9b-4042-955d-6945930fc93c',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T02:52:03.796+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:20:25.222+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '44271f2d-03af-4d0e-821f-150d313016ab'},
#     {'end': 33,
#      'tag': 'Behavioral',
#      'start': 29,
#      'value': 'BUSY',
#      'tag_id': '4e4637f2-48c3-452e-b7db-d1cace295a4d',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '6b763b00-ef9b-4042-955d-6945930fc93c',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T02:52:03.792+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:20:45.199+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'c6e454b4-a0f3-4cbe-9311-c183eef624a7'},
#     {'end': 17,
#      'tag': 'Biological Kind',
#      'start': 9,
#      'value': 'CELESTIA',
#      'tag_id': 'b3c56c74-2d45-483d-945d-9103cf870c36',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '6b763b00-ef9b-4042-955d-6945930fc93c',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T02:52:03.79+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:20:41.084+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'cd9855b9-fcec-49f0-a5ce-b3b1d95e920d'},
#     {'end': 28,
#      'tag': 'Perceptual',
#      'start': 22,
#      'value': 'LITTLE',
#      'tag_id': '3302eb94-c347-42d4-a94e-fa696faadced',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '6b763b00-ef9b-4042-955d-6945930fc93c',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:20:25.205+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'd0d23bc6-34a8-41cc-8cec-b272a10910ce'},
#     {'end': 78,
#      'tag': 'Social Kind/Role',
#      'start': 67,
#      'value': 'CELEBRATION',
#      'tag_id': 'c2d08238-bcff-4c44-af7c-74c991a2afb3',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '6b763b00-ef9b-4042-955d-6945930fc93c',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T02:52:03.798+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:20:51.483+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'e558fa81-0af6-41ff-aec0-7fc3b25ed7f8'},
#     {'end': 47,
#      'tag': 'Perceptual',
#      'start': 42,
#      'value': 'READY',
#      'tag_id': '3302eb94-c347-42d4-a94e-fa696faadced',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '6b763b00-ef9b-4042-955d-6945930fc93c',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:20:25.214+00:00',
#        'annotator_id': 1},
#       {'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T02:52:03.794+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'fef76a49-246d-4278-8ae9-ed195304a29b'},
#     {'end': 8,
#      'tag': 'Social Kind/Role',
#      'start': 0,
#      'value': 'PRINCESS',
#      'tag_id': 'c2d08238-bcff-4c44-af7c-74c991a2afb3',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '6b763b00-ef9b-4042-955d-6945930fc93c',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:20:25.197+00:00',
#        'annotator_id': 1},
#       {'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T02:52:03.789+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '02ec7ebf-7e96-4ffc-91e6-33b485774ff0'}],
#    'classifications': []},
#   {'content': "And we have four baby koalas that we're caring for at the moment.",
#    'seen_by': [{'annotator': 'rileydc@stanford.edu', 'annotator_id': 1},
#     {'annotator': 'syu03@stanford.edu', 'annotator_id': 4}],
#    'comments': [],
#    'metadata': {},
#    'example_id': '78cb384f-f90f-4d66-9055-1aa8b87cfea1',
#    'annotations': [{'end': 11,
#      'tag': 'Behavioral',
#      'start': 7,
#      'value': 'have',
#      'tag_id': '4e4637f2-48c3-452e-b7db-d1cace295a4d',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '78cb384f-f90f-4d66-9055-1aa8b87cfea1',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:26:46.042+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:52:28.436+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'aaf6e557-5555-4929-bf80-64df3afd6cdf'},
#     {'end': 21,
#      'tag': 'Biological Kind',
#      'start': 17,
#      'value': 'baby',
#      'tag_id': 'b3c56c74-2d45-483d-945d-9103cf870c36',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '78cb384f-f90f-4d66-9055-1aa8b87cfea1',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:52:28.446+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'aec0ee3d-775f-4370-ac87-cfbb3e075cf4'},
#     {'end': 46,
#      'tag': 'Behavioral',
#      'start': 40,
#      'value': 'caring',
#      'tag_id': '4e4637f2-48c3-452e-b7db-d1cace295a4d',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '78cb384f-f90f-4d66-9055-1aa8b87cfea1',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:52:28.454+00:00',
#        'annotator_id': 1},
#       {'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:26:46.049+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '8a35528a-2354-43b1-abcd-36faa15f34bc'},
#     {'end': 28,
#      'tag': 'Biological Kind',
#      'start': 22,
#      'value': 'koalas',
#      'tag_id': 'b3c56c74-2d45-483d-945d-9103cf870c36',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '78cb384f-f90f-4d66-9055-1aa8b87cfea1',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:52:54.655+00:00',
#        'annotator_id': 1},
#       {'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:26:46.046+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '9a0edaff-a951-4689-b076-63080f071b8e'},
#     {'end': 6,
#      'tag': 'Biological Kind',
#      'start': 4,
#      'value': 'we',
#      'tag_id': 'b3c56c74-2d45-483d-945d-9103cf870c36',
#      'correct': True,
#      'reviewed': True,
# ...
#        'timestamp': '2023-09-09T02:55:17.228+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:30:52.739+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'e786206a-eaa8-495d-a9a2-4f623a967894'},
#     {'end': 63,
#      'tag': 'Behavioral',
#      'start': 56,
#      'value': 'show up',
#      'tag_id': '4e4637f2-48c3-452e-b7db-d1cace295a4d',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '27a950ba-731c-46e5-92d2-b808e27b8c15',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T02:55:17.235+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:31:09.807+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '62f6a66d-e59d-48c3-b084-93ddb11bc74f'},
#     {'end': 81,
#      'tag': 'Biological Kind',
#      'start': 80,
#      'value': 'I',
#      'tag_id': 'b3c56c74-2d45-483d-945d-9103cf870c36',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '27a950ba-731c-46e5-92d2-b808e27b8c15',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T02:55:30.978+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:32:09.508+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '4563bc95-198a-4010-82d5-736442224be5'},
#     {'end': 17,
#      'tag': 'Perceptual',
#      'start': 12,
#      'value': 'small',
#      'tag_id': '3302eb94-c347-42d4-a94e-fa696faadced',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '27a950ba-731c-46e5-92d2-b808e27b8c15',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:30:52.735+00:00',
#        'annotator_id': 1},
#       {'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T02:55:17.226+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '88c819d2-79ae-4074-9bf6-6d8cedc4ee46'},
#     {'end': 4,
#      'tag': 'Biological Kind',
#      'start': 3,
#      'value': 'I',
#      'tag_id': 'b3c56c74-2d45-483d-945d-9103cf870c36',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '27a950ba-731c-46e5-92d2-b808e27b8c15',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T02:55:20.564+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:31:01.561+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '02b3047c-ab8c-4711-a517-820492486b8d'},
#     {'end': 4,
#      'tag': 'Anthropomorphized',
#      'start': 3,
#      'value': 'I',
#      'tag_id': '3d4327e2-56d5-4da0-a591-1aac6ff5fa9d',
#      'correct': False,
#      'reviewed': True,
#      'example_id': '27a950ba-731c-46e5-92d2-b808e27b8c15',
#      'annotated_by': [{'annotator': None,
#        'timestamp': None,
#        'annotator_id': None}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '0f2d34cf-abdb-44f9-8a8a-ec60086334c6'},
#     {'end': 55,
#      'tag': 'Social Kind/Role',
#      'start': 51,
#      'value': 'city',
#      'tag_id': 'c2d08238-bcff-4c44-af7c-74c991a2afb3',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '27a950ba-731c-46e5-92d2-b808e27b8c15',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T02:55:17.234+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:30:52.747+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '2b24d19b-fc94-4c27-8e38-423ea3979378'},
#     {'end': 106,
#      'tag': 'Behavioral',
#      'start': 97,
#      'value': 'witnessed',
#      'tag_id': '4e4637f2-48c3-452e-b7db-d1cace295a4d',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '27a950ba-731c-46e5-92d2-b808e27b8c15',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:33:14.106+00:00',
#        'annotator_id': 1},
#       {'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T02:55:17.238+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'd4237bd3-c16b-428d-bbd2-7cac6c677c0d'},
#     {'end': 50,
#      'tag': 'Perceptual',
#      'start': 47,
#      'value': 'new',
#      'tag_id': '3302eb94-c347-42d4-a94e-fa696faadced',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '27a950ba-731c-46e5-92d2-b808e27b8c15',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T02:55:17.233+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:30:52.743+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '25cb0cb7-eca5-4240-8770-1601560dd867'},
#     {'end': 40,
#      'tag': 'Behavioral',
#      'start': 31,
#      'value': 'disappear',
#      'tag_id': '4e4637f2-48c3-452e-b7db-d1cace295a4d',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '27a950ba-731c-46e5-92d2-b808e27b8c15',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:31:05.661+00:00',
#        'annotator_id': 1},
#       {'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T02:55:17.232+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '80681d37-1be4-41cf-84d6-3da6615c2d00'}],
#    'classifications': []},
#   {'content': 'They can live to over 60 years old, and the stages of their lives are similar to ours.',
#    'seen_by': [{'annotator': 'rileydc@stanford.edu', 'annotator_id': 1},
#     {'annotator': 'syu03@stanford.edu', 'annotator_id': 4}],
#    'comments': [],
#    'metadata': {},
#    'example_id': '2514ac1a-ab50-47f9-8215-a289800c9a76',
#    'annotations': [{'end': 13,
#      'tag': 'Behavioral',
#      'start': 9,
#      'value': 'live',
#      'tag_id': '4e4637f2-48c3-452e-b7db-d1cace295a4d',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '2514ac1a-ab50-47f9-8215-a289800c9a76',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:00:08.377+00:00',
#        'annotator_id': 1},
#       {'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:29:11.606+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'f0033ed5-2590-4451-b216-bc8f216b03a5'},
#     {'end': 4,
#      'tag': 'Biological Kind',
#      'start': 0,
#      'value': 'They',
#      'tag_id': 'b3c56c74-2d45-483d-945d-9103cf870c36',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '2514ac1a-ab50-47f9-8215-a289800c9a76',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:29:11.603+00:00',
#        'annotator_id': 4},
#       {'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:00:00.682+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'abb63bd1-418a-4a4a-acfe-f19029242e64'},
#     {'end': 59,
#      'tag': 'Anthropomorphized',
#      'start': 54,
#      'value': 'their',
#      'tag_id': '3d4327e2-56d5-4da0-a591-1aac6ff5fa9d',
#      'correct': None,
#      'reviewed': False,
#      'example_id': '2514ac1a-ab50-47f9-8215-a289800c9a76',
#      'annotated_by': [{'annotator': None,
#        'timestamp': None,
#        'annotator_id': None}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'bfceaf69-584a-42f2-b8d2-9773ae7ee567'},
#     {'end': 77,
#      'tag': 'Relation',
#      'start': 70,
#      'value': 'similar',
#      'tag_id': '4ae5d3ef-e700-4ab3-8e95-d3aa1fb17007',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '2514ac1a-ab50-47f9-8215-a289800c9a76',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:00:17.013+00:00',
#        'annotator_id': 1},
#       {'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T07:29:11.614+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '39ec8491-37ee-41b7-8f48-d4b74d073e9e'},
#     {'end': 24,
#      'tag': 'Perceptual',
#      'start': 22,
#      'value': '60',
#      'tag_id': '3302eb94-c347-42d4-a94e-fa696faadced',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '2514ac1a-ab50-47f9-8215-a289800c9a76',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:00:05.955+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'e4b63953-bcfd-4ef8-925d-21ea8f283fb9'},
#     {'end': 65,
#      'tag': 'Behavioral',
#      'start': 60,
#      'value': 'lives',
#      'tag_id': '4e4637f2-48c3-452e-b7db-d1cace295a4d',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '2514ac1a-ab50-47f9-8215-a289800c9a76',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:00:00.706+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'bcb56627-f152-4ab9-be5a-89c3d944feb5'},
#     {'end': 30,
#      'tag': 'Non-Living Kind',
#      'start': 25,
#      'value': 'years',
#      'tag_id': 'a4288773-f6c5-4bc8-8dff-2b16b8f4787e',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '2514ac1a-ab50-47f9-8215-a289800c9a76',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:00:00.692+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'f6891505-93ad-41bd-a646-8db4a2b11bf8'},
#     {'end': 34,
#      'tag': 'Perceptual',
#      'start': 31,
#      'value': 'old',
#      'tag_id': '3302eb94-c347-42d4-a94e-fa696faadced',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '2514ac1a-ab50-47f9-8215-a289800c9a76',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-09T00:00:00.697+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'b429fd1b-6b23-46ab-b5b1-aad47c03ce10'}],
#    'classifications': []},
#   {'content': 'Being the seeker is just as important as hiding.',
#    'seen_by': [{'annotator': 'rileydc@stanford.edu', 'annotator_id': 1},
#     {'annotator': 'syu03@stanford.edu', 'annotator_id': 4}],
#    'comments': [],
#    'metadata': {},
#    'example_id': '0cd11216-75c3-4498-ac6a-cc0171462ead',
#    'annotations': [{'end': 16,
#      'tag': 'Behavioral',
#      'start': 10,
#      'value': 'seeker',
#      'tag_id': '4e4637f2-48c3-452e-b7db-d1cace295a4d',
#      'correct': False,
#      'reviewed': True,
#      'example_id': '0cd11216-75c3-4498-ac6a-cc0171462ead',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:30:06.932+00:00',
#        'annotator_id': 1}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '86357cf9-09e3-4543-b606-859c8889504c'},
#     {'end': 47,
#      'tag': 'Behavioral',
#      'start': 41,
#      'value': 'hiding',
#      'tag_id': '4e4637f2-48c3-452e-b7db-d1cace295a4d',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '0cd11216-75c3-4498-ac6a-cc0171462ead',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:30:10.389+00:00',
#        'annotator_id': 1},
#       {'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T02:54:11.792+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '21a2ee7b-cdbd-411d-931b-4b90167b5ba2'},
#     {'end': 37,
#      'tag': 'Normative Feature',
#      'start': 28,
#      'value': 'important',
#      'tag_id': '81d95dea-443c-4f17-9c59-090e5377b894',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '0cd11216-75c3-4498-ac6a-cc0171462ead',
#      'annotated_by': [{'annotator': 'rileydc@stanford.edu',
#        'timestamp': '2023-09-08T23:30:14.941+00:00',
#        'annotator_id': 1},
#       {'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T02:54:11.791+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': 'cbd6ef1f-82d0-4ab9-ab3b-4c8f6962f6bd'},
#     {'end': 16,
#      'tag': 'Social Kind/Role',
#      'start': 10,
#      'value': 'seeker',
#      'tag_id': 'c2d08238-bcff-4c44-af7c-74c991a2afb3',
#      'correct': True,
#      'reviewed': True,
#      'example_id': '0cd11216-75c3-4498-ac6a-cc0171462ead',
#      'annotated_by': [{'annotator': 'syu03@stanford.edu',
#        'timestamp': '2023-09-09T02:54:24.416+00:00',
#        'annotator_id': 4}],
#      'definition_id': '9edcbaba-a0f6-4ce5-a7e5-d7075911b698',
#      'tagged_token_id': '00177a3c-72dc-4fd6-a627-4b27c52ab4f9'}],
#    'classifications': []}],
#  'schema': {'id': '9d90a5f3-8fc4-44a6-941e-90759361cb7a',
#   'archived': False,
#   'slug': 'book_v2',
#   'name': 'Book_V2',
#   'tags': [{'id': '3d4327e2-56d5-4da0-a591-1aac6ff5fa9d',
#     'name': 'Anthropomorphized',
#     'description': '',
#     'schema_id': '9d90a5f3-8fc4-44a6-941e-90759361cb7a'},
#    {'id': '93766023-3257-4bed-8223-6f91c904c834',
#     'name': 'Artifacts',
#     'description': '',
#     'schema_id': '9d90a5f3-8fc4-44a6-941e-90759361cb7a'},
#    {'id': '4e4637f2-48c3-452e-b7db-d1cace295a4d',
#     'name': 'Behavioral',
#     'description': '',
#     'schema_id': '9d90a5f3-8fc4-44a6-941e-90759361cb7a'},
#    {'id': 'b3c56c74-2d45-483d-945d-9103cf870c36',
#     'name': 'Biological Kind',
#     'description': '',
#     'schema_id': '9d90a5f3-8fc4-44a6-941e-90759361cb7a'},
#    {'id': '2507aaa4-514e-4c68-aa12-4ec759d2625b',
#     'name': 'Mental State',
#     'description': '',
#     'schema_id': '9d90a5f3-8fc4-44a6-941e-90759361cb7a'},
#    {'id': 'a4288773-f6c5-4bc8-8dff-2b16b8f4787e',
#     'name': 'Non-Living Kind',
#     'description': '',
#     'schema_id': '9d90a5f3-8fc4-44a6-941e-90759361cb7a'},
#    {'id': '81d95dea-443c-4f17-9c59-090e5377b894',
#     'name': 'Normative Feature',
#     'description': '',
#     'schema_id': '9d90a5f3-8fc4-44a6-941e-90759361cb7a'},
#    {'id': '3302eb94-c347-42d4-a94e-fa696faadced',
#     'name': 'Perceptual',
#     'description': '',
#     'schema_id': '9d90a5f3-8fc4-44a6-941e-90759361cb7a'},
#    {'id': 'dd07eb87-383b-46b8-89c7-657bb418576d',
#     'name': 'Purpose',
#     'description': '',
#     'schema_id': '9d90a5f3-8fc4-44a6-941e-90759361cb7a'},
#    {'id': '4ae5d3ef-e700-4ab3-8e95-d3aa1fb17007',
#     'name': 'Relation',
#     'description': '',
#     'schema_id': '9d90a5f3-8fc4-44a6-941e-90759361cb7a'},
#    {'id': 'c2d08238-bcff-4c44-af7c-74c991a2afb3',
#     'name': 'Social Kind/Role',
#     'description': '',
#     'schema_id': '9d90a5f3-8fc4-44a6-941e-90759361cb7a'}],
#   'classification_types': [],
#   'models': [{'id': '34faea13-8c7e-4eee-8b59-be0c555aa620',
#     'url': '/api/v2/models/34faea13-8c7e-4eee-8b59-be0c555aa620/',
#     'slug': 'book_v2-ad-hoc-dict',
#     'name': 'Book_V2 ad hoc dict',
#     'metadata': {},
#     'schema_id': '9d90a5f3-8fc4-44a6-941e-90759361cb7a'}],
#   'editable': False,
#   'is_multiclass': False},
#  'dataset': {'id': 'adf10dbc-70c0-4473-9b71-5dd3ef5120d0',
#   'slug': 'shows',
#   'url': '/api/v1/projects/default/datasets/shows/',
#   'name': 'Shows',
#   'id_field': None,
#   'content_field': 'Content',
#   'aggregation_field': None,
#   'order_field': None,
#   'upload_status': 'started',
#   'archived': False,
#   'editable': False},
#  'relations': [],
#  'name': 'Show Transcript',
#  'annotators_per_example': '3'}

# %%
all_annotations = []

for i in range(len(df1['examples'])):
    example = df1['examples'][i]
    sentence = example['content']
    sentence_id = example['example_id']  # Assuming 'id' is the sentence identifier in your JSON data
    
    for f in example['annotations']:
        if f['correct'] == False or f['reviewed'] == False:
            continue
        
        word = f['value']
        label = f['tag']
        start = f['start']  # Assuming 'start' is the start position of the word
        end = f['end']      # Assuming 'end' is the end position of the word
        
        d = {
            'sentence': sentence,
            'sentence_id': sentence_id,
            'word': word,
            'label': label,
            'start': start,
            'end': end
        }
        
        all_annotations.append(d)

# %%
all_annotations
# Out:
# [{'sentence': 'let me just double check there',
#   'sentence_id': '207e43bd-33d0-4015-86f5-e3742943fc0a',
#   'word': 'check',
#   'label': 'Behavioral',
#   'start': 19,
#   'end': 24},
#  {'sentence': 'let me just double check there',
#   'sentence_id': '207e43bd-33d0-4015-86f5-e3742943fc0a',
#   'word': 'double',
#   'label': 'Perceptual',
#   'start': 12,
#   'end': 18},
#  {'sentence': 'let me just double check there',
#   'sentence_id': '207e43bd-33d0-4015-86f5-e3742943fc0a',
#   'word': 'me',
#   'label': 'Biological Kind',
#   'start': 4,
#   'end': 6},
#  {'sentence': 'what are you doing huh',
#   'sentence_id': '677e16cb-3282-45be-b535-9347fb092d08',
#   'word': 'doing',
#   'label': 'Behavioral',
#   'start': 13,
#   'end': 18},
#  {'sentence': 'what are you doing huh',
#   'sentence_id': '677e16cb-3282-45be-b535-9347fb092d08',
#   'word': 'you',
#   'label': 'Biological Kind',
#   'start': 9,
#   'end': 12},
#  {'sentence': 'I gotta put my sister',
#   'sentence_id': '8f873564-bf07-48bb-981e-0508526128c5',
#   'word': 'put',
#   'label': 'Behavioral',
#   'start': 8,
#   'end': 11},
#  {'sentence': 'I gotta put my sister',
#   'sentence_id': '8f873564-bf07-48bb-981e-0508526128c5',
#   'word': 'gotta',
#   'label': 'Behavioral',
#   'start': 2,
#   'end': 7},
#  {'sentence': 'I gotta put my sister',
#   'sentence_id': '8f873564-bf07-48bb-981e-0508526128c5',
#   'word': 'sister',
#   'label': 'Social Kind/Role',
#   'start': 15,
#   'end': 21},
#  {'sentence': 'I gotta put my sister',
#   'sentence_id': '8f873564-bf07-48bb-981e-0508526128c5',
#   'word': 'I',
#   'label': 'Biological Kind',
#   'start': 0,
#   'end': 1},
#  {'sentence': "yes you're ready",
#   'sentence_id': '376571a2-ef3c-4a09-a8b9-fcf90a6497b8',
#   'word': 'you',
#   'label': 'Biological Kind',
#   'start': 4,
#   'end': 7},
#  {'sentence': "yes you're ready",
#   'sentence_id': '376571a2-ef3c-4a09-a8b9-fcf90a6497b8',
#   'word': 'ready',
#   'label': 'Behavioral',
#   'start': 11,
#   'end': 16},
#  {'sentence': "it's baby xxx",
#   'sentence_id': '3d75d246-41fa-4cd8-b84d-de321e69ab6f',
#   'word': 'baby',
#   'label': 'Biological Kind',
#   'start': 5,
#   'end': 9},
#  {'sentence': 'bite their heads',
#   'sentence_id': 'f923a3bc-5e72-4926-82fd-4a6b08638bc0',
#   'word': 'heads',
#   'label': 'Biological Kind',
#   'start': 11,
#   'end': 16},
#  {'sentence': 'bite their heads',
#   'sentence_id': 'f923a3bc-5e72-4926-82fd-4a6b08638bc0',
#   'word': 'bite',
#   'label': 'Behavioral',
#   'start': 0,
#   'end': 4},
#  {'sentence': 'close your eyes and visualize and xxx',
#   'sentence_id': '649c3718-b352-41d3-b61b-20bf993747b7',
#   'word': 'visualize',
#   'label': 'Behavioral',
#   'start': 20,
#   'end': 29},
#  {'sentence': 'close your eyes and visualize and xxx',
#   'sentence_id': '649c3718-b352-41d3-b61b-20bf993747b7',
#   'word': 'close',
#   'label': 'Behavioral',
#   'start': 0,
#   'end': 5},
#  {'sentence': 'close your eyes and visualize and xxx',
#   'sentence_id': '649c3718-b352-41d3-b61b-20bf993747b7',
#   'word': 'eyes',
#   'label': 'Biological Kind',
#   'start': 11,
#   'end': 15},
#  {'sentence': 'it falls',
#   'sentence_id': '00f85ce9-a72e-464f-ba5d-0db652c3e771',
#   'word': 'falls',
#   'label': 'Behavioral',
#   'start': 3,
#   'end': 8},
#  {'sentence': 'can you say hi Amanda',
#   'sentence_id': '07dfb029-196c-4db6-a7c9-fff69233d4c3',
#   'word': 'you',
#   'label': 'Biological Kind',
#   'start': 4,
#   'end': 7},
#  {'sentence': 'can you say hi Amanda',
#   'sentence_id': '07dfb029-196c-4db6-a7c9-fff69233d4c3',
#   'word': 'Amanda',
#   'label': 'Biological Kind',
#   'start': 15,
#   'end': 21},
#  {'sentence': 'can you say hi Amanda',
#   'sentence_id': '07dfb029-196c-4db6-a7c9-fff69233d4c3',
#   'word': 'say',
#   'label': 'Behavioral',
#   'start': 8,
#   'end': 11},
#  {'sentence': 'bye Willie',
#   'sentence_id': '9076ac33-60c7-4ef1-8a6b-b3d25587c2ec',
#   'word': 'Willie',
#   'label': 'Biological Kind',
#   'start': 4,
#   'end': 10},
#  {'sentence': 'bye Willie',
#   'sentence_id': '9076ac33-60c7-4ef1-8a6b-b3d25587c2ec',
#   'word': 'bye',
#   'label': 'Behavioral',
#   'start': 0,
#   'end': 3},
#  {'sentence': 'and you can have it back',
#   'sentence_id': '85c18f6a-6bcc-45b5-801d-eb44d6bf9a7d',
#   'word': 'have',
#   'label': 'Behavioral',
#   'start': 12,
#   'end': 16},
#  {'sentence': 'and you can have it back',
#   'sentence_id': '85c18f6a-6bcc-45b5-801d-eb44d6bf9a7d',
#   'word': 'you',
#   'label': 'Biological Kind',
#   'start': 4,
#   'end': 7},
#  {'sentence': 'right Patrick',
#   'sentence_id': '5a999420-86c4-4a4a-bc06-7a082d101515',
#   'word': 'right',
#   'label': 'Normative Feature',
#   'start': 0,
#   'end': 5},
#  {'sentence': 'right Patrick',
#   'sentence_id': '5a999420-86c4-4a4a-bc06-7a082d101515',
#   'word': 'Patrick',
#   'label': 'Biological Kind',
#   'start': 6,
#   'end': 13},
#  {'sentence': 'in that little tiny hole',
#   'sentence_id': 'cab691b2-409d-43a3-bc4b-e5ed7e5f30e8',
#   'word': 'little',
#   'label': 'Perceptual',
#   'start': 8,
#   'end': 14},
#  {'sentence': 'in that little tiny hole',
#   'sentence_id': 'cab691b2-409d-43a3-bc4b-e5ed7e5f30e8',
#   'word': 'hole',
#   'label': 'Non-Living Kind',
#   'start': 20,
#   'end': 24},
#  {'sentence': 'in that little tiny hole',
#   'sentence_id': 'cab691b2-409d-43a3-bc4b-e5ed7e5f30e8',
#   'word': 'tiny',
#   'label': 'Perceptual',
#   'start': 15,
#   'end': 19},
#  {'sentence': 'piles of fish',
#   'sentence_id': '6d588384-2453-4771-b98e-f89a77e53b31',
#   'word': 'piles',
#   'label': 'Perceptual',
#   'start': 0,
#   'end': 5},
#  {'sentence': 'piles of fish',
#   'sentence_id': '6d588384-2453-4771-b98e-f89a77e53b31',
#   'word': 'fish',
#   'label': 'Biological Kind',
#   'start': 9,
#   'end': 13},
#  {'sentence': 'toys',
#   'sentence_id': '35b4b262-9f1c-4c26-ad14-4c3f37096fc1',
#   'word': 'toys',
#   'label': 'Artifacts',
#   'start': 0,
#   'end': 4},
#  {'sentence': 'what should I do in the microphone',
#   'sentence_id': '066830e3-7509-4141-b861-0f91433e5f39',
#   'word': 'microphone',
#   'label': 'Artifacts',
#   'start': 24,
#   'end': 34},
#  {'sentence': 'what should I do in the microphone',
#   'sentence_id': '066830e3-7509-4141-b861-0f91433e5f39',
#   'word': 'do',
#   'label': 'Behavioral',
#   'start': 14,
#   'end': 16},
#  {'sentence': 'what should I do in the microphone',
#   'sentence_id': '066830e3-7509-4141-b861-0f91433e5f39',
#   'word': 'I',
#   'label': 'Biological Kind',
#   'start': 12,
#   'end': 13},
#  {'sentence': 'you make it come this finger come back',
#   'sentence_id': 'a2acc98f-1675-4517-9352-edd8c94ad94c',
#   'word': 'come',
#   'label': 'Behavioral',
#   'start': 29,
#   'end': 33},
#  {'sentence': 'you make it come this finger come back',
#   'sentence_id': 'a2acc98f-1675-4517-9352-edd8c94ad94c',
#   'word': 'back',
#   'label': 'Relation',
#   'start': 34,
#   'end': 38},
#  {'sentence': 'you make it come this finger come back',
#   'sentence_id': 'a2acc98f-1675-4517-9352-edd8c94ad94c',
#   'word': 'come',
#   'label': 'Behavioral',
#   'start': 12,
#   'end': 16},
#  {'sentence': 'you make it come this finger come back',
#   'sentence_id': 'a2acc98f-1675-4517-9352-edd8c94ad94c',
#   'word': 'finger',
#   'label': 'Biological Kind',
#   'start': 22,
#   'end': 28},
#  {'sentence': 'you make it come this finger come back',
#   'sentence_id': 'a2acc98f-1675-4517-9352-edd8c94ad94c',
#   'word': 'make',
#   'label': 'Behavioral',
#   'start': 4,
#   'end': 8},
#  {'sentence': 'you make it come this finger come back',
#   'sentence_id': 'a2acc98f-1675-4517-9352-edd8c94ad94c',
#   'word': 'you',
#   'label': 'Biological Kind',
#   'start': 0,
#   'end': 3},
#  {'sentence': 'come on',
#   'sentence_id': '1b8875ed-8aa7-4649-9705-e66001a30163',
#   'word': 'come',
#   'label': 'Behavioral',
#   'start': 0,
#   'end': 4},
#  {'sentence': 'how can he be so hungry huh',
#   'sentence_id': 'e94b6f6a-167a-44f6-8a1b-329b1000e709',
#   'word': 'he',
#   'label': 'Biological Kind',
#   'start': 8,
#   'end': 10},
#  {'sentence': 'how can he be so hungry huh',
#   'sentence_id': 'e94b6f6a-167a-44f6-8a1b-329b1000e709',
#   'word': 'hungry',
#   'label': 'Mental State',
#   'start': 17,
#   'end': 23},
#  {'sentence': 'come on',
#   'sentence_id': '3eba2e5d-8efe-4731-861b-cb1fb5bcfb55',
#   'word': 'come',
#   'label': 'Behavioral',
#   'start': 0,
#   'end': 4},
#  {'sentence': 'Dad can you pick that up',
#   'sentence_id': '5f778ccc-279b-4126-b6c3-a7a4535cdd04',
#   'word': 'you',
#   'label': 'Biological Kind',
#   'start': 8,
#   'end': 11},
#  {'sentence': 'Dad can you pick that up',
#   'sentence_id': '5f778ccc-279b-4126-b6c3-a7a4535cdd04',
#   'word': 'Dad',
#   'label': 'Biological Kind',
#   'start': 0,
#   'end': 3},
#  {'sentence': 'Dad can you pick that up',
#   'sentence_id': '5f778ccc-279b-4126-b6c3-a7a4535cdd04',
#   'word': 'pick',
#   'label': 'Behavioral',
#   'start': 12,
#   'end': 16},
#  {'sentence': 'I see your cookie',
#   'sentence_id': '50aaf740-100c-495b-bf64-519bb45a3777',
#   'word': 'see',
#   'label': 'Behavioral',
#   'start': 2,
#   'end': 5},
#  {'sentence': 'I see your cookie',
#   'sentence_id': '50aaf740-100c-495b-bf64-519bb45a3777',
#   'word': 'I',
#   'label': 'Biological Kind',
#   'start': 0,
#   'end': 1},
#  {'sentence': 'I see your cookie',
#   'sentence_id': '50aaf740-100c-495b-bf64-519bb45a3777',
#   'word': 'cookie',
#   'label': 'Artifacts',
#   'start': 11,
#   'end': 17},
#  {'sentence': 'remember we made these beautiful flowers',
#   'sentence_id': '9d124721-78d7-4389-84fb-475baac287ec',
#   'word': 'flowers',
#   'label': 'Biological Kind',
#   'start': 33,
#   'end': 40},
#  {'sentence': 'remember we made these beautiful flowers',
#   'sentence_id': '9d124721-78d7-4389-84fb-475baac287ec',
#   'word': 'remember',
#   'label': 'Mental State',
#   'start': 0,
#   'end': 8},
#  {'sentence': 'remember we made these beautiful flowers',
#   'sentence_id': '9d124721-78d7-4389-84fb-475baac287ec',
#   'word': 'made',
#   'label': 'Behavioral',
#   'start': 12,
#   'end': 16},
#  {'sentence': 'remember we made these beautiful flowers',
#   'sentence_id': '9d124721-78d7-4389-84fb-475baac287ec',
#   'word': 'beautiful',
#   'label': 'Normative Feature',
#   'start': 23,
#   'end': 32},
#  {'sentence': 'remember we made these beautiful flowers',
#   'sentence_id': '9d124721-78d7-4389-84fb-475baac287ec',
#   'word': 'we',
#   'label': 'Biological Kind',
#   'start': 9,
#   'end': 11},
#  {'sentence': 'not win',
#   'sentence_id': '9407e1fb-cd47-45c6-b41d-aecc5e8e9c20',
#   'word': 'win',
#   'label': 'Behavioral',
#   'start': 4,
#   'end': 7},
#  {'sentence': 'xxx make the Play_Doh',
#   'sentence_id': 'aa3e5313-ae8d-4146-bdd7-99739f78303e',
#   'word': 'make',
#   'label': 'Behavioral',
#   'start': 4,
#   'end': 8},
#  {'sentence': 'xxx make the Play_Doh',
#   'sentence_id': 'aa3e5313-ae8d-4146-bdd7-99739f78303e',
#   'word': 'Play_Doh',
#   'label': 'Artifacts',
#   'start': 13,
#   'end': 21},
#  {'sentence': 'yeah we did buy a snow sled at the toy store',
#   'sentence_id': '6f82325a-a946-401f-8b37-5520d85b3049',
#   'word': 'snow sled',
#   'label': 'Artifacts',
#   'start': 18,
#   'end': 27},
#  {'sentence': 'yeah we did buy a snow sled at the toy store',
#   'sentence_id': '6f82325a-a946-401f-8b37-5520d85b3049',
#   'word': 'we',
#   'label': 'Biological Kind',
#   'start': 5,
#   'end': 7},
#  {'sentence': 'yeah we did buy a snow sled at the toy store',
#   'sentence_id': '6f82325a-a946-401f-8b37-5520d85b3049',
#   'word': 'buy',
#   'label': 'Behavioral',
#   'start': 12,
#   'end': 15},
#  {'sentence': 'yeah we did buy a snow sled at the toy store',
#   'sentence_id': '6f82325a-a946-401f-8b37-5520d85b3049',
#   'word': 'toy',
#   'label': 'Artifacts',
#   'start': 35,
#   'end': 38},
#  {'sentence': 'yeah we did buy a snow sled at the toy store',
#   'sentence_id': '6f82325a-a946-401f-8b37-5520d85b3049',
#   'word': 'store',
#   'label': 'Social Kind/Role',
#   'start': 39,
#   'end': 44},
#  {'sentence': 'were you scared',
#   'sentence_id': '212af0c1-27bd-4abf-8451-16e57c3650ae',
#   'word': 'scared',
#   'label': 'Mental State',
#   'start': 9,
#   'end': 15},
#  {'sentence': 'were you scared',
#   'sentence_id': '212af0c1-27bd-4abf-8451-16e57c3650ae',
#   'word': 'you',
#   'label': 'Biological Kind',
#   'start': 5,
#   'end': 8},
#  {'sentence': 'when you when I came to see you at the hospital',
#   'sentence_id': '5828b5b9-5489-438b-a05c-df34f6b863a1',
#   'word': 'you',
#   'label': 'Biological Kind',
#   'start': 5,
#   'end': 8},
#  {'sentence': 'when you when I came to see you at the hospital',
#   'sentence_id': '5828b5b9-5489-438b-a05c-df34f6b863a1',
#   'word': 'hospital',
#   'label': 'Social Kind/Role',
#   'start': 39,
#   'end': 47},
#  {'sentence': 'when you when I came to see you at the hospital',
#   'sentence_id': '5828b5b9-5489-438b-a05c-df34f6b863a1',
#   'word': 'came',
#   'label': 'Behavioral',
#   'start': 16,
#   'end': 20},
#  {'sentence': 'when you when I came to see you at the hospital',
#   'sentence_id': '5828b5b9-5489-438b-a05c-df34f6b863a1',
#   'word': 'you',
#   'label': 'Biological Kind',
#   'start': 28,
#   'end': 31},
#  {'sentence': 'when you when I came to see you at the hospital',
#   'sentence_id': '5828b5b9-5489-438b-a05c-df34f6b863a1',
#   'word': 'see',
#   'label': 'Behavioral',
#   'start': 24,
#   'end': 27},
#  {'sentence': 'when you when I came to see you at the hospital',
#   'sentence_id': '5828b5b9-5489-438b-a05c-df34f6b863a1',
#   'word': 'I',
#   'label': 'Biological Kind',
#   'start': 14,
#   'end': 15},
#  {'sentence': "xxx that's silly",
#   'sentence_id': 'abe59539-a6aa-4ce9-afae-2496c9883bad',
#   'word': 'silly',
#   'label': 'Normative Feature',
#   'start': 11,
#   'end': 16},
#  {'sentence': "you're right it is too big",
#   'sentence_id': '4f5d67de-21d5-4b61-bea8-6cac0da6a633',
#   'word': 'you',
#   'label': 'Biological Kind',
#   'start': 0,
#   'end': 3},
#  {'sentence': "you're right it is too big",
#   'sentence_id': '4f5d67de-21d5-4b61-bea8-6cac0da6a633',
#   'word': 'big',
#   'label': 'Perceptual',
#   'start': 23,
#   'end': 26},
#  {'sentence': "you're right it is too big",
#   'sentence_id': '4f5d67de-21d5-4b61-bea8-6cac0da6a633',
#   'word': 'right',
#   'label': 'Normative Feature',
#   'start': 7,
#   'end': 12},
#  {'sentence': "um and it seems like it's a job that people stay with",
#   'sentence_id': '8dd05ae3-d9a6-45f4-8c79-30960a0bfeb4',
#   'word': 'job',
#   'label': 'Social Kind/Role',
#   'start': 28,
#   'end': 31},
#  {'sentence': "um and it seems like it's a job that people stay with",
#   'sentence_id': '8dd05ae3-d9a6-45f4-8c79-30960a0bfeb4',
#   'word': 'people',
#   'label': 'Biological Kind',
#   'start': 37,
#   'end': 43},
#  {'sentence': "um and it seems like it's a job that people stay with",
#   'sentence_id': '8dd05ae3-d9a6-45f4-8c79-30960a0bfeb4',
#   'word': 'stay',
#   'label': 'Behavioral',
#   'start': 44,
#   'end': 48},
#  {'sentence': 'okay are your eyes closed',
#   'sentence_id': '082f107e-7b8b-4795-9003-c765ea04fbef',
#   'word': 'eyes',
#   'label': 'Biological Kind',
#   'start': 14,
#   'end': 18},
#  {'sentence': 'okay are your eyes closed',
#   'sentence_id': '082f107e-7b8b-4795-9003-c765ea04fbef',
#   'word': 'closed',
#   'label': 'Behavioral',
#   'start': 19,
#   'end': 25},
#  {'sentence': 'the little girl wore it everyday and that is why she is called Little Red Riding Hood',
#   'sentence_id': '860718a7-e370-43c7-a706-4bd555c763ed',
#   'word': 'little',
#   'label': 'Perceptual',
#   'start': 4,
#   'end': 10},
#  {'sentence': 'the little girl wore it everyday and that is why she is called Little Red Riding Hood',
#   'sentence_id': '860718a7-e370-43c7-a706-4bd555c763ed',
#   'word': 'called',
#   'label': 'Behavioral',
#   'start': 56,
#   'end': 62},
#  {'sentence': 'the little girl wore it everyday and that is why she is called Little Red Riding Hood',
#   'sentence_id': '860718a7-e370-43c7-a706-4bd555c763ed',
#   'word': 'wore',
#   'label': 'Behavioral',
#   'start': 16,
#   'end': 20},
#  {'sentence': 'the little girl wore it everyday and that is why she is called Little Red Riding Hood',
#   'sentence_id': '860718a7-e370-43c7-a706-4bd555c763ed',
#   'word': 'she',
#   'label': 'Biological Kind',
#   'start': 49,
#   'end': 52},
#  {'sentence': 'the little girl wore it everyday and that is why she is called Little Red Riding Hood',
#   'sentence_id': '860718a7-e370-43c7-a706-4bd555c763ed',
#   'word': 'girl',
#   'label': 'Social Kind/Role',
#   'start': 11,
#   'end': 15},
#  {'sentence': 'the little girl wore it everyday and that is why she is called Little Red Riding Hood',
#   'sentence_id': '860718a7-e370-43c7-a706-4bd555c763ed',
#   'word': 'Little Red Riding Hood',
#   'label': 'Biological Kind',
#   'start': 63,
#   'end': 85},
#  {'sentence': 'well what you gonna get me for Christmas',
#   'sentence_id': '09a7fcca-b792-4186-839d-5eafcc40d672',
#   'word': 'get',
#   'label': 'Behavioral',
#   'start': 20,
#   'end': 23},
#  {'sentence': 'well what you gonna get me for Christmas',
#   'sentence_id': '09a7fcca-b792-4186-839d-5eafcc40d672',
#   'word': 'gonna',
#   'label': 'Behavioral',
#   'start': 14,
#   'end': 19},
#  {'sentence': 'well what you gonna get me for Christmas',
#   'sentence_id': '09a7fcca-b792-4186-839d-5eafcc40d672',
#   'word': 'Christmas',
#   'label': 'Social Kind/Role',
#   'start': 31,
#   'end': 40},
#  {'sentence': 'well what you gonna get me for Christmas',
#   'sentence_id': '09a7fcca-b792-4186-839d-5eafcc40d672',
#   'word': 'you',
#   'label': 'Biological Kind',
#   'start': 10,
#   'end': 13},
#  {'sentence': 'well what you gonna get me for Christmas',
#   'sentence_id': '09a7fcca-b792-4186-839d-5eafcc40d672',
#   'word': 'me',
#   'label': 'Biological Kind',
#   'start': 24,
#   'end': 26},
#  {'sentence': "um uh its little back opens I don't know what that's called but to um and then those are the wings",
#   'sentence_id': '503f4f5e-19e2-4ca7-b528-b86f75ca1526',
#   'word': 'called',
#   'label': 'Behavioral',
#   'start': 53,
#   'end': 59},
#  {'sentence': "um uh its little back opens I don't know what that's called but to um and then those are the wings",
#   'sentence_id': '503f4f5e-19e2-4ca7-b528-b86f75ca1526',
#   'word': 'little',
#   'label': 'Perceptual',
#   'start': 10,
#   'end': 16},
#  {'sentence': "um uh its little back opens I don't know what that's called but to um and then those are the wings",
#   'sentence_id': '503f4f5e-19e2-4ca7-b528-b86f75ca1526',
#   'word': 'back',
#   'label': 'Relation',
#   'start': 17,
#   'end': 21},
#  {'sentence': "um uh its little back opens I don't know what that's called but to um and then those are the wings",
#   'sentence_id': '503f4f5e-19e2-4ca7-b528-b86f75ca1526',
#   'word': 'I',
#   'label': 'Biological Kind',
#   'start': 28,
#   'end': 29},
#  {'sentence': "um uh its little back opens I don't know what that's called but to um and then those are the wings",
#   'sentence_id': '503f4f5e-19e2-4ca7-b528-b86f75ca1526',
#   'word': 'wings',
#   'label': 'Biological Kind',
#   'start': 93,
#   'end': 98},
#  {'sentence': "um uh its little back opens I don't know what that's called but to um and then those are the wings",
#   'sentence_id': '503f4f5e-19e2-4ca7-b528-b86f75ca1526',
#   'word': 'opens',
#   'label': 'Behavioral',
#   'start': 22,
#   'end': 27},
#  {'sentence': "um uh its little back opens I don't know what that's called but to um and then those are the wings",
#   'sentence_id': '503f4f5e-19e2-4ca7-b528-b86f75ca1526',
#   'word': 'know',
#   'label': 'Behavioral',
#   'start': 36,
#   'end': 40},
#  {'sentence': 'you wanna read it with me',
#   'sentence_id': 'd2a71806-65aa-49a5-af39-9aec267305ea',
#   'word': 'wanna',
#   'label': 'Mental State',
#   'start': 4,
#   'end': 9},
#  {'sentence': 'you wanna read it with me',
#   'sentence_id': 'd2a71806-65aa-49a5-af39-9aec267305ea',
#   'word': 'me',
#   'label': 'Biological Kind',
#   'start': 23,
#   'end': 25},
#  {'sentence': 'you wanna read it with me',
#   'sentence_id': 'd2a71806-65aa-49a5-af39-9aec267305ea',
#   'word': 'you',
#   'label': 'Biological Kind',
#   'start': 0,
#   'end': 3},
#  {'sentence': 'you wanna read it with me',
#   'sentence_id': 'd2a71806-65aa-49a5-af39-9aec267305ea',
#   'word': 'read',
#   'label': 'Behavioral',
#   'start': 10,
#   'end': 14},
#  {'sentence': "we'll hafta go look for it",
#   'sentence_id': '6af16e92-e31b-4521-92ad-6c859fbb305e',
#   'word': 'go',
#   'label': 'Behavioral',
#   'start': 12,
#   'end': 14},
#  {'sentence': "we'll hafta go look for it",
#   'sentence_id': '6af16e92-e31b-4521-92ad-6c859fbb305e',
#   'word': 'we',
#   'label': 'Biological Kind',
#   'start': 0,
#   'end': 2},
#  {'sentence': "we'll hafta go look for it",
#   'sentence_id': '6af16e92-e31b-4521-92ad-6c859fbb305e',
#   'word': 'look',
#   'label': 'Behavioral',
#   'start': 15,
#   'end': 19},
#  {'sentence': 'read me this',
#   'sentence_id': '476d1b45-ec74-45e6-a019-94c2190119c5',
#   'word': 'read',
#   'label': 'Behavioral',
#   'start': 0,
#   'end': 4},
#  {'sentence': 'read me this',
#   'sentence_id': '476d1b45-ec74-45e6-a019-94c2190119c5',
#   'word': 'me',
#   'label': 'Biological Kind',
#   'start': 5,
#   'end': 7},
#  {'sentence': "we'll do some more later",
#   'sentence_id': '0b8832c4-bd50-484a-9d7e-cbb537e1f5f4',
#   'word': 'we',
#   'label': 'Biological Kind',
#   'start': 0,
#   'end': 2},
#  {'sentence': "there you can find there's an elephant but see you hafta lay them out on the floor",
#   'sentence_id': '1fd24708-3427-4231-be9a-e1e29aa34973',
#   'word': 'you',
#   'label': 'Biological Kind',
#   'start': 6,
#   'end': 9},
#  {'sentence': "there you can find there's an elephant but see you hafta lay them out on the floor",
#   'sentence_id': '1fd24708-3427-4231-be9a-e1e29aa34973',
#   'word': 'find',
#   'label': 'Behavioral',
#   'start': 14,
#   'end': 18},
#  {'sentence': "there you can find there's an elephant but see you hafta lay them out on the floor",
#   'sentence_id': '1fd24708-3427-4231-be9a-e1e29aa34973',
#   'word': 'lay',
#   'label': 'Behavioral',
#   'start': 57,
#   'end': 60},
#  {'sentence': "there you can find there's an elephant but see you hafta lay them out on the floor",
#   'sentence_id': '1fd24708-3427-4231-be9a-e1e29aa34973',
#   'word': 'you',
#   'label': 'Biological Kind',
#   'start': 47,
#   'end': 50},
#  {'sentence': "there you can find there's an elephant but see you hafta lay them out on the floor",
#   'sentence_id': '1fd24708-3427-4231-be9a-e1e29aa34973',
#   'word': 'see',
#   'label': 'Behavioral',
#   'start': 43,
#   'end': 46},
#  {'sentence': "there you can find there's an elephant but see you hafta lay them out on the floor",
#   'sentence_id': '1fd24708-3427-4231-be9a-e1e29aa34973',
#   'word': 'them',
#   'label': 'Biological Kind',
#   'start': 61,
#   'end': 65},
#  {'sentence': "there you can find there's an elephant but see you hafta lay them out on the floor",
#   'sentence_id': '1fd24708-3427-4231-be9a-e1e29aa34973',
#   'word': 'elephant',
#   'label': 'Biological Kind',
#   'start': 30,
#   'end': 38},
#  {'sentence': "there you can find there's an elephant but see you hafta lay them out on the floor",
#   'sentence_id': '1fd24708-3427-4231-be9a-e1e29aa34973',
#   'word': 'floor',
#   'label': 'Non-Living Kind',
#   'start': 77,
#   'end': 82},
#  {'sentence': 'xxx try and do the other one',
#   'sentence_id': 'd7bd6dce-c05f-45a3-8310-cd893b66f264',
#   'word': 'one',
#   'label': 'Perceptual',
#   'start': 25,
#   'end': 28},
#  {'sentence': 'xxx try and do the other one',
#   'sentence_id': 'd7bd6dce-c05f-45a3-8310-cd893b66f264',
#   'word': 'try',
#   'label': 'Behavioral',
#   'start': 4,
#   'end': 7},
#  {'sentence': "what's the name of that song",
#   'sentence_id': '2fe87019-a29d-4469-b10e-90be392356da',
#   'word': 'song',
#   'label': 'Artifacts',
#   'start': 24,
#   'end': 28},
#  {'sentence': "what's the name of that song",
#   'sentence_id': '2fe87019-a29d-4469-b10e-90be392356da',
#   'word': 'name',
#   'label': 'Social Kind/Role',
#   'start': 11,
#   'end': 15},
#  {'sentence': 'this bee has weird hair feel that',
#   'sentence_id': '4260a995-d8f0-47c5-9a8d-b6b81ecf1590',
#   'word': 'hair',
#   'label': 'Biological Kind',
#   'start': 19,
#   'end': 23},
#  {'sentence': 'this bee has weird hair feel that',
#   'sentence_id': '4260a995-d8f0-47c5-9a8d-b6b81ecf1590',
#   'word': 'weird',
#   'label': 'Normative Feature',
#   'start': 13,
#   'end': 18},
#  {'sentence': 'this bee has weird hair feel that',
#   'sentence_id': '4260a995-d8f0-47c5-9a8d-b6b81ecf1590',
#   'word': 'bee',
#   'label': 'Biological Kind',
#   'start': 5,
#   'end': 8},
#  {'sentence': 'this bee has weird hair feel that',
#   'sentence_id': '4260a995-d8f0-47c5-9a8d-b6b81ecf1590',
#   'word': 'feel',
#   'label': 'Mental State',
#   'start': 24,
#   'end': 28},
#  {'sentence': 'Dada',
#   'sentence_id': 'e57e28af-9a1b-405b-96fc-cd12c8a4f8aa',
#   'word': 'Dada',
#   'label': 'Social Kind/Role',
#   'start': 0,
#   'end': 4},
#  {'sentence': 'wanna floppy',
#   'sentence_id': '4675dc3b-fbd7-426e-8848-6ac898679fbb',
#   'word': 'floppy',
#   'label': 'Behavioral',
#   'start': 6,
#   'end': 12},
#  {'sentence': 'wanna floppy',
#   'sentence_id': '4675dc3b-fbd7-426e-8848-6ac898679fbb',
#   'word': 'wanna',
#   'label': 'Mental State',
#   'start': 0,
#   'end': 5},
#  {'sentence': 'there you go',
#   'sentence_id': 'a5d7648c-5407-4fc2-b3b9-8aeaf16774b9',
#   'word': 'go',
#   'label': 'Behavioral',
#   'start': 10,
#   'end': 12},
#  {'sentence': 'there you go',
#   'sentence_id': 'a5d7648c-5407-4fc2-b3b9-8aeaf16774b9',
#   'word': 'you',
#   'label': 'Biological Kind',
#   'start': 6,
#   'end': 9},
#  {'sentence': 'are you silly',
#   'sentence_id': 'e74eeb15-417a-462e-b111-d86d7f2de2a9',
#   'word': 'you',
#   'label': 'Biological Kind',
#   'start': 4,
#   'end': 7},
#  {'sentence': 'are you silly',
#   'sentence_id': 'e74eeb15-417a-462e-b111-d86d7f2de2a9',
#   'word': 'silly',
#   'label': 'Normative Feature',
#   'start': 8,
#   'end': 13},
#  {'sentence': 'call me up',
#   'sentence_id': 'be1b2269-3288-4960-a14d-45f4b2cfe31f',
#   'word': 'call',
#   'label': 'Behavioral',
#   'start': 0,
#   'end': 4},
#  {'sentence': 'call me up',
#   'sentence_id': 'be1b2269-3288-4960-a14d-45f4b2cfe31f',
#   'word': 'me',
#   'label': 'Biological Kind',
#   'start': 5,
#   'end': 7},
#  {'sentence': 'get away',
#   'sentence_id': 'd948b809-91ec-443f-9380-f50818b7604f',
#   'word': 'get',
#   'label': 'Behavioral',
#   'start': 0,
#   'end': 3},
#  {'sentence': 'get away',
#   'sentence_id': 'd948b809-91ec-443f-9380-f50818b7604f',
#   'word': 'away',
#   'label': 'Relation',
#   'start': 4,
#   'end': 8},
#  {'sentence': 'can I do it',
#   'sentence_id': 'c555ef52-4a1e-4fff-8f9a-1639f2d46330',
#   'word': 'do',
#   'label': 'Behavioral',
#   'start': 6,
#   'end': 8},
#  {'sentence': 'can I do it',
#   'sentence_id': 'c555ef52-4a1e-4fff-8f9a-1639f2d46330',
#   'word': 'I',
#   'label': 'Biological Kind',
#   'start': 4,
#   'end': 5},
#  {'sentence': 'then she came and got them',
#   'sentence_id': '0ddc94b4-2fa7-4cc9-8fbd-603a87db8966',
#   'word': 'came',
#   'label': 'Behavioral',
#   'start': 9,
#   'end': 13},
#  {'sentence': 'then she came and got them',
#   'sentence_id': '0ddc94b4-2fa7-4cc9-8fbd-603a87db8966',
#   'word': 'she',
#   'label': 'Biological Kind',
#   'start': 5,
#   'end': 8},
#  {'sentence': 'then she came and got them',
#   'sentence_id': '0ddc94b4-2fa7-4cc9-8fbd-603a87db8966',
#   'word': 'got',
#   'label': 'Behavioral',
#   'start': 18,
#   'end': 21},
#  {'sentence': 'then she came and got them',
#   'sentence_id': '0ddc94b4-2fa7-4cc9-8fbd-603a87db8966',
#   'word': 'them',
#   'label': 'Biological Kind',
#   'start': 22,
#   'end': 26},
#  {'sentence': 'keep the keep the money in here',
#   'sentence_id': '3d431a68-be65-4642-84c0-54475c49e8e5',
#   'word': 'money',
#   'label': 'Social Kind/Role',
#   'start': 18,
#   'end': 23},
#  {'sentence': 'keep the keep the money in here',
#   'sentence_id': '3d431a68-be65-4642-84c0-54475c49e8e5',
#   'word': 'keep',
#   'label': 'Behavioral',
#   'start': 0,
#   'end': 4},
#  {'sentence': 'keep the keep the money in here',
#   'sentence_id': '3d431a68-be65-4642-84c0-54475c49e8e5',
#   'word': 'keep',
#   'label': 'Behavioral',
#   'start': 9,
#   'end': 13},
#  {'sentence': 'that one popped',
#   'sentence_id': '7094021e-4348-4c87-ba7d-8fb2a4cfa7e5',
#   'word': 'popped',
#   'label': 'Behavioral',
#   'start': 9,
#   'end': 15},
#  {'sentence': 'that one popped',
#   'sentence_id': '7094021e-4348-4c87-ba7d-8fb2a4cfa7e5',
#   'word': 'one',
#   'label': 'Perceptual',
#   'start': 5,
#   'end': 8},
#  {'sentence': "hm this one's Texas what's the other big state",
#   'sentence_id': '1dec8419-af27-4064-b826-2080fbbf66ce',
#   'word': 'state',
#   'label': 'Social Kind/Role',
#   'start': 41,
#   'end': 46},
#  {'sentence': "hm this one's Texas what's the other big state",
#   'sentence_id': '1dec8419-af27-4064-b826-2080fbbf66ce',
#   'word': 'Texas',
#   'label': 'Social Kind/Role',
#   'start': 14,
#   'end': 19},
#  {'sentence': "hm this one's Texas what's the other big state",
#   'sentence_id': '1dec8419-af27-4064-b826-2080fbbf66ce',
#   'word': 'one',
#   'label': 'Perceptual',
#   'start': 8,
#   'end': 11},
#  {'sentence': "hm this one's Texas what's the other big state",
#   'sentence_id': '1dec8419-af27-4064-b826-2080fbbf66ce',
#   'word': 'big',
#   'label': 'Perceptual',
#   'start': 37,
#   'end': 40},
#  {'sentence': 'need a cow',
#   'sentence_id': 'f3315935-a4a4-4e4c-b45f-80683b76b980',
#   'word': 'cow',
#   'label': 'Biological Kind',
#   'start': 7,
#   'end': 10},
#  {'sentence': 'need a cow',
#   'sentence_id': 'f3315935-a4a4-4e4c-b45f-80683b76b980',
#   'word': 'need',
#   'label': 'Mental State',
#   'start': 0,
#   'end': 4},
#  {'sentence': "I can't see",
#   'sentence_id': 'd0a0da35-1198-41b8-be35-a30887f67278',
#   'word': 'I',
#   'label': 'Biological Kind',
#   'start': 0,
#   'end': 1},
#  {'sentence': "I can't see",
#   'sentence_id': 'd0a0da35-1198-41b8-be35-a30887f67278',
#   'word': 'see',
#   'label': 'Behavioral',
#   'start': 8,
#   'end': 11},
#  {'sentence': 'those are great huh',
#   'sentence_id': '8d3b3845-0691-4f31-b1ab-27707d8d0947',
#   'word': 'great',
#   'label': 'Perceptual',
#   'start': 10,
#   'end': 15},
#  {'sentence': "I don't think so",
#   'sentence_id': '87204d74-8aca-4356-9888-dfdde891d21e',
#   'word': 'think',
#   'label': 'Mental State',
#   'start': 8,
#   'end': 13},
#  {'sentence': "I don't think so",
#   'sentence_id': '87204d74-8aca-4356-9888-dfdde891d21e',
#   'word': 'I',
#   'label': 'Biological Kind',
#   'start': 0,
#   'end': 1},
#  {'sentence': 'there we go',
#   'sentence_id': '912fe957-f6f8-4434-9940-b55df0fdf2d8',
#   'word': 'we',
#   'label': 'Biological Kind',
#   'start': 6,
#   'end': 8},
#  {'sentence': 'there we go',
#   'sentence_id': '912fe957-f6f8-4434-9940-b55df0fdf2d8',
#   'word': 'go',
#   'label': 'Behavioral',
#   'start': 9,
#   'end': 11},
#  {'sentence': 'all the toys on the floor it looks like home',
#   'sentence_id': '8e147188-e594-46f9-9a71-661d406066bf',
#   'word': 'looks',
#   'label': 'Behavioral',
#   'start': 29,
#   'end': 34},
#  {'sentence': 'all the toys on the floor it looks like home',
#   'sentence_id': '8e147188-e594-46f9-9a71-661d406066bf',
#   'word': 'toys',
#   'label': 'Artifacts',
#   'start': 8,
#   'end': 12},
#  {'sentence': 'all the toys on the floor it looks like home',
#   'sentence_id': '8e147188-e594-46f9-9a71-661d406066bf',
#   'word': 'floor',
#   'label': 'Non-Living Kind',
#   'start': 20,
#   'end': 25},
#  {'sentence': 'all the toys on the floor it looks like home',
#   'sentence_id': '8e147188-e594-46f9-9a71-661d406066bf',
#   'word': 'home',
#   'label': 'Artifacts',
#   'start': 40,
#   'end': 44},
#  {'sentence': "this is Lulu's baby brother",
#   'sentence_id': 'e1c44e56-14f2-400e-bc55-4e8937ceae57',
#   'word': 'baby',
#   'label': 'Biological Kind',
#   'start': 15,
#   'end': 19},
#  {'sentence': "this is Lulu's baby brother",
#   'sentence_id': 'e1c44e56-14f2-400e-bc55-4e8937ceae57',
#   'word': 'brother',
#   'label': 'Social Kind/Role',
#   'start': 20,
#   'end': 27},
#  {'sentence': "this is Lulu's baby brother",
#   'sentence_id': 'e1c44e56-14f2-400e-bc55-4e8937ceae57',
#   'word': 'Lulu',
#   'label': 'Biological Kind',
#   'start': 8,
#   'end': 12},
#  {'sentence': 'and the end of the cone in pointy',
#   'sentence_id': '3a775726-95dd-4a12-8808-0ba59487efd2',
#   'word': 'cone',
#   'label': 'Artifacts',
#   'start': 19,
#   'end': 23},
#  {'sentence': 'and the end of the cone in pointy',
#   'sentence_id': '3a775726-95dd-4a12-8808-0ba59487efd2',
#   'word': 'end',
#   'label': 'Relation',
#   'start': 8,
#   'end': 11},
#  {'sentence': 'and the end of the cone in pointy',
#   'sentence_id': '3a775726-95dd-4a12-8808-0ba59487efd2',
#   'word': 'pointy',
#   'label': 'Perceptual',
#   'start': 27,
#   'end': 33},
#  {'sentence': 'your fire truck all a both of your fire trucks are going up',
#   'sentence_id': '35669af3-3716-421f-9de8-24f9abc3e5cc',
#   'word': 'fire truck',
#   'label': 'Artifacts',
#   'start': 5,
#   'end': 15},
#  {'sentence': 'your fire truck all a both of your fire trucks are going up',
#   'sentence_id': '35669af3-3716-421f-9de8-24f9abc3e5cc',
#   'word': 'going',
#   'label': 'Behavioral',
#   'start': 51,
#   'end': 56},
#  {'sentence': 'your fire truck all a both of your fire trucks are going up',
#   'sentence_id': '35669af3-3716-421f-9de8-24f9abc3e5cc',
#   'word': 'fire trucks',
#   'label': 'Artifacts',
#   'start': 35,
#   'end': 46},
#  {'sentence': "what's this collared",
#   'sentence_id': 'b9e237e5-31ce-42d1-abd5-1588692ba7ae',
#   'word': 'collared',
#   'label': 'Artifacts',
#   'start': 12,
#   'end': 20},
#  {'sentence': 'a very nice tune',
#   'sentence_id': '82c8ac89-7b15-4835-bf25-aad9f8b3b7da',
#   'word': 'nice',
#   'label': 'Normative Feature',
#   'start': 7,
#   'end': 11},
#  {'sentence': 'a very nice tune',
#   'sentence_id': '82c8ac89-7b15-4835-bf25-aad9f8b3b7da',
#   'word': 'tune',
#   'label': 'Social Kind/Role',
#   'start': 12,
#   'end': 16},
#  {'sentence': 'haha is that fun',
#   'sentence_id': '4782d2cc-7602-4eef-832c-b9229bbbbaff',
#   'word': 'fun',
#   'label': 'Normative Feature',
#   'start': 13,
#   'end': 16},
#  {'sentence': 'excuse me',
#   'sentence_id': '48e7932a-cbbe-4f08-8fb3-23646cf95e00',
#   'word': 'me',
#   'label': 'Biological Kind',
#   'start': 7,
#   'end': 9},
#  {'sentence': 'excuse me',
#   'sentence_id': '48e7932a-cbbe-4f08-8fb3-23646cf95e00',
#   'word': 'excuse',
#   'label': 'Behavioral',
#   'start': 0,
#   'end': 6},
#  {'sentence': 'the elephants fell',
#   'sentence_id': 'e4d8ea65-498c-4073-8d75-c2a783e70b41',
#   'word': 'fell',
#   'label': 'Behavioral',
#   'start': 14,
#   'end': 18},
#  {'sentence': 'the elephants fell',
#   'sentence_id': 'e4d8ea65-498c-4073-8d75-c2a783e70b41',
#   'word': 'elephants',
#   'label': 'Biological Kind',
#   'start': 4,
#   'end': 13},
#  {'sentence': 'put it on',
#   'sentence_id': '7674e188-2e03-4c82-af2d-64530b0dbf72',
#   'word': 'put',
#   'label': 'Behavioral',
#   'start': 0,
#   'end': 3},
#  {'sentence': "let's make believe we can't find him said Danny",
#   'sentence_id': 'cda031ab-ee06-4120-9c32-9c7ccafd2d29',
#   'word': 'him',
#   'label': 'Biological Kind',
#   'start': 33,
#   'end': 36},
#  {'sentence': "let's make believe we can't find him said Danny",
#   'sentence_id': 'cda031ab-ee06-4120-9c32-9c7ccafd2d29',
#   'word': 'we',
#   'label': 'Biological Kind',
#   'start': 19,
#   'end': 21},
#  {'sentence': "let's make believe we can't find him said Danny",
#   'sentence_id': 'cda031ab-ee06-4120-9c32-9c7ccafd2d29',
#   'word': 'said',
#   'label': 'Behavioral',
#   'start': 37,
#   'end': 41},
#  {'sentence': "let's make believe we can't find him said Danny",
#   'sentence_id': 'cda031ab-ee06-4120-9c32-9c7ccafd2d29',
#   'word': 'believe',
#   'label': 'Mental State',
#   'start': 11,
#   'end': 18},
#  {'sentence': "let's make believe we can't find him said Danny",
#   'sentence_id': 'cda031ab-ee06-4120-9c32-9c7ccafd2d29',
#   'word': 'make',
#   'label': 'Behavioral',
#   'start': 6,
#   'end': 10},
#  {'sentence': "let's make believe we can't find him said Danny",
#   'sentence_id': 'cda031ab-ee06-4120-9c32-9c7ccafd2d29',
#   'word': 'find',
#   'label': 'Behavioral',
#   'start': 28,
#   'end': 32},
#  {'sentence': "let's make believe we can't find him said Danny",
#   'sentence_id': 'cda031ab-ee06-4120-9c32-9c7ccafd2d29',
#   'word': 'Danny',
#   'label': 'Biological Kind',
#   'start': 42,
#   'end': 47},
#  {'sentence': 'but gulp oh no I swallowed it',
#   'sentence_id': '6ae80d5a-3bba-4e75-811f-7366158ab508',
#   'word': 'I',
#   'label': 'Biological Kind',
#   'start': 15,
#   'end': 16},
#  {'sentence': 'but gulp oh no I swallowed it',
#   'sentence_id': '6ae80d5a-3bba-4e75-811f-7366158ab508',
#   'word': 'swallowed',
#   'label': 'Behavioral',
#   'start': 17,
#   'end': 26},
#  {'sentence': 'but gulp oh no I swallowed it',
#   'sentence_id': '6ae80d5a-3bba-4e75-811f-7366158ab508',
#   'word': 'gulp',
#   'label': 'Behavioral',
#   'start': 4,
#   'end': 8},
#  {'sentence': 'how do you pick out Floppy in every picture',
#   'sentence_id': '6fc4b06f-39aa-433f-afe8-c63f39ae11a6',
#   'word': 'picture',
#   'label': 'Artifacts',
#   'start': 36,
#   'end': 43},
#  {'sentence': 'how do you pick out Floppy in every picture',
#   'sentence_id': '6fc4b06f-39aa-433f-afe8-c63f39ae11a6',
#   'word': 'you',
#   'label': 'Biological Kind',
#   'start': 7,
#   'end': 10},
#  {'sentence': 'how do you pick out Floppy in every picture',
#   'sentence_id': '6fc4b06f-39aa-433f-afe8-c63f39ae11a6',
#   'word': 'Floppy',
#   'label': 'Biological Kind',
#   'start': 20,
#   'end': 26},
#  {'sentence': 'how do you pick out Floppy in every picture',
#   'sentence_id': '6fc4b06f-39aa-433f-afe8-c63f39ae11a6',
#   'word': 'pick',
#   'label': 'Behavioral',
#   'start': 11,
#   'end': 15},
#  {'sentence': 'twenty two twenty three',
#   'sentence_id': '32172e5c-ebed-4385-acc2-4b7d4892e988',
#   'word': 'three',
#   'label': 'Perceptual',
#   'start': 18,
#   'end': 23},
#  {'sentence': 'twenty two twenty three',
#   'sentence_id': '32172e5c-ebed-4385-acc2-4b7d4892e988',
#   'word': 'twenty',
#   'label': 'Perceptual',
#   'start': 11,
#   'end': 17},
#  {'sentence': 'twenty two twenty three',
#   'sentence_id': '32172e5c-ebed-4385-acc2-4b7d4892e988',
#   'word': 'twenty',
#   'label': 'Perceptual',
#   'start': 0,
#   'end': 6},
#  {'sentence': 'twenty two twenty three',
#   'sentence_id': '32172e5c-ebed-4385-acc2-4b7d4892e988',
#   'word': 'two',
#   'label': 'Perceptual',
#   'start': 7,
#   'end': 10},
#  {'sentence': 'a boy or a girl',
#   'sentence_id': 'b219d3a4-e219-4053-9855-719877d57520',
#   'word': 'boy',
#   'label': 'Social Kind/Role',
#   'start': 2,
#   'end': 5},
#  {'sentence': 'a boy or a girl',
#   'sentence_id': 'b219d3a4-e219-4053-9855-719877d57520',
#   'word': 'girl',
#   'label': 'Social Kind/Role',
#   'start': 11,
#   'end': 15},
#  {'sentence': 'do you drive',
#   'sentence_id': '1270034d-9727-4709-8f45-5006f8c0d4a6',
#   'word': 'drive',
#   'label': 'Behavioral',
#   'start': 7,
#   'end': 12},
#  {'sentence': 'do you drive',
#   'sentence_id': '1270034d-9727-4709-8f45-5006f8c0d4a6',
#   'word': 'you',
#   'label': 'Biological Kind',
#   'start': 3,
#   'end': 6},
#  {'sentence': "I think that's a baby isn't it",
#   'sentence_id': 'def6df18-51c7-49e3-ab0c-81db1e4bdc93',
#   'word': 'I',
#   'label': 'Biological Kind',
#   'start': 0,
#   'end': 1},
#  {'sentence': "I think that's a baby isn't it",
#   'sentence_id': 'def6df18-51c7-49e3-ab0c-81db1e4bdc93',
#   'word': 'baby',
#   'label': 'Biological Kind',
#   'start': 17,
#   'end': 21},
#  {'sentence': "I think that's a baby isn't it",
#   'sentence_id': 'def6df18-51c7-49e3-ab0c-81db1e4bdc93',
#   'word': 'think',
#   'label': 'Mental State',
#   'start': 2,
#   'end': 7},
#  {'sentence': "that's a zebra",
#   'sentence_id': 'bd3ca7ff-fa46-4491-8946-ac1330cfa2cd',
#   'word': 'zebra',
#   'label': 'Biological Kind',
#   'start': 9,
#   'end': 14},
#  {'sentence': 'well I will do it',
#   'sentence_id': 'ef8dd1aa-5360-4540-9670-c8aeccbde8c1',
#   'word': 'do',
#   'label': 'Behavioral',
#   'start': 12,
#   'end': 14},
#  {'sentence': 'well I will do it',
#   'sentence_id': 'ef8dd1aa-5360-4540-9670-c8aeccbde8c1',
#   'word': 'I',
#   'label': 'Biological Kind',
#   'start': 5,
#   'end': 6},
#  {'sentence': 'can I have the key',
#   'sentence_id': 'fc5f90c1-69a1-48f1-8546-33071ecce8b4',
#   'word': 'I',
#   'label': 'Biological Kind',
#   'start': 4,
#   'end': 5},
#  {'sentence': 'can I have the key',
#   'sentence_id': 'fc5f90c1-69a1-48f1-8546-33071ecce8b4',
#   'word': 'key',
#   'label': 'Artifacts',
#   'start': 15,
#   'end': 18},
#  {'sentence': 'can I have the key',
#   'sentence_id': 'fc5f90c1-69a1-48f1-8546-33071ecce8b4',
#   'word': 'have',
#   'label': 'Behavioral',
#   'start': 6,
#   'end': 10},
#  {'sentence': "xxx it's a beaver",
#   'sentence_id': 'cc6e3ec2-783a-4106-a7f2-6dd969062e52',
#   'word': 'beaver',
#   'label': 'Biological Kind',
#   'start': 11,
#   'end': 17},
#  {'sentence': 'you maybe sitting on it',
#   'sentence_id': '248b7cdb-01a2-4f24-8868-5919e44b89c3',
#   'word': 'sitting',
#   'label': 'Behavioral',
#   'start': 10,
#   'end': 17},
#  {'sentence': 'you maybe sitting on it',
#   'sentence_id': '248b7cdb-01a2-4f24-8868-5919e44b89c3',
#   'word': 'you',
#   'label': 'Biological Kind',
#   'start': 0,
#   'end': 3}]

# %%
with open("validation_parents.json", 'w', encoding='utf-8') as json_file:
    json.dump(all_annotations, json_file, ensure_ascii=False, indent=4)
